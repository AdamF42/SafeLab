# %% [markdown]
# ## Importing the relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats.distributions import chi2 
from math import sqrt
import seaborn as sns
sns.set()
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from influxdb_client import InfluxDBClient

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the Data and Pre-processing

# %%
df = pd.read_csv("dataframe_11g_5m.csv")
df.time = pd.to_datetime(df.time, dayfirst = True)
df.set_index('time',inplace=True)
points_per_day = 288 
n_days = 11
df = df.drop(columns=['humidity', 'pressure', 'people'])
df
# Out:
#                            temperature
# time
# 2020-07-07 13:30:00+00:00        29.70
# 2020-07-07 13:35:00+00:00        29.70
# 2020-07-07 13:40:00+00:00        29.70
# 2020-07-07 13:45:00+00:00        29.75
# 2020-07-07 13:50:00+00:00        29.75
# ...                                ...
# 2020-07-18 13:05:00+00:00        29.25
# 2020-07-18 13:10:00+00:00        29.25
# 2020-07-18 13:15:00+00:00        29.25
# 2020-07-18 13:20:00+00:00        29.25
# 2020-07-18 13:25:00+00:00        29.25
#
# [3168 rows x 1 columns]

# %% [markdown]
# # Fill NaN values

# %%
df['temperature'] = df['temperature'].fillna(method='backfill').fillna(method='ffill')

# %%
points_per_day = int(len(df)/n_days) 
points_per_day
# Out:
# 288

# %%
print(df['temperature'].isnull().sum())
# Out:
# 0

# %% [markdown]
# # Split the dataset

# %%
# divide in train e test
#size = int(len(df)*0.8)
size = len(df)-points_per_day
df_train, df_test = df.iloc[:size], df.iloc[size:]

# %% [markdown]
# # Dickey–Fuller test

# %%
sts.adfuller(df.temperature) # stazionaria
# Out:
# (-4.3218030067351245,
#  0.00040713953032198814,
#  28,
#  3139,
#  {'1%': -3.43243494922729,
#   '5%': -2.8624612019435536,
#   '10%': -2.5672603774676577},
#  -5579.439576253486)

# %% [markdown]
# ## The LLR Test

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.llf
    L2 = mod_2.llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %% [markdown]
# ## Auto Correlation Function (ACF)

# %%
sgt.plot_acf(df.temperature, zero = False, lags = 1000)
plt.title("ACF 4 temperature", size = 20)
plt.show()

# %% [markdown]
# ## Partial Auto Correlation Function (PACF)

# %%
sgt.plot_pacf(df.temperature, lags = 40, alpha = 0.05, zero = False, method = ('ols'))
plt.title("PACF 4 temperature", size = 20)
plt.show()

# %% [markdown]
# # Temperature

# %%
start_date = df_test.index[0]
end_date = df_test.index[24]#df_test.index[points_per_day-1]

# %% [markdown]
# ## AR

# %%
print("AR(1)")
model_t_ar_1 = SARIMAX(df_train.temperature, order=(1,0,0))
results_t_ar_1 = model_t_ar_1.fit()
print(results_t_ar_1.summary())

print("AR(2)") #PARAMETRI NON SIGNIFICATIVI
model_t_ar_2 = SARIMAX(df_train.temperature, order=(2,0,0))
results_t_ar_2 = model_t_ar_2.fit()
print(results_t_ar_2.summary())

print("AR(3)") #PARAMETRI NON SIGNIFICATIVI
model_t_ar_3 = SARIMAX(df_train.temperature, order=(3,0,0))
results_t_ar_3 = model_t_ar_3.fit()
print(results_t_ar_3.summary())

print("AR(4)") #PARAMETRI NON SIGNIFICATIVI
model_t_ar_4 = ARIMA(df_train.temperature, order=(4,0,0))
results_t_ar_4 = model_t_ar_4.fit()
print(results_t_ar_4.summary())

print("AR(5)") 
model_t_ar_5 = ARIMA(df_train.temperature, order=(5,0,0))
results_t_ar_5 = model_t_ar_5.fit()
print(results_t_ar_5.summary())
# Out:
# AR(1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                2262.752
# Date:                Mon, 20 Jul 2020   AIC                          -4521.503
# Time:                        14:35:33   BIC                          -4509.572
# Sample:                    07-07-2020   HQIC                         -4517.203
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000   3.15e-05   3.17e+04      0.000       1.000       1.000
# sigma2         0.0121      0.000    110.574      0.000       0.012       0.012
# ===================================================================================
# Ljung-Box (Q):                      703.25   Jarque-Bera (JB):             32151.22
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                             2.08
# Prob(H) (two-sided):                  0.93   Kurtosis:                        18.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                2262.752
# Date:                Mon, 20 Jul 2020   AIC                          -4519.503
# Time:                        14:35:33   BIC                          -4501.606
# Sample:                    07-07-2020   HQIC                         -4513.052
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      4.541      0.220      0.826      -7.901       9.901
# ar.L2      -2.789e-06      4.541  -6.14e-07      1.000      -8.901       8.901
# sigma2         0.0121      0.000    105.263      0.000       0.012       0.012
# ===================================================================================
# Ljung-Box (Q):                      703.25   Jarque-Bera (JB):             32151.19
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.99   Skew:                             2.08
# Prob(H) (two-sided):                  0.93   Kurtosis:                        18.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 0, 0)   Log Likelihood                2447.157
# Date:                Mon, 20 Jul 2020   AIC                          -4886.315
# Time:                        14:35:34   BIC                          -4862.453
# Sample:                    07-07-2020   HQIC                         -4877.714
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      3.478      0.288      0.774      -5.817       7.817
# ar.L2          0.3469      3.476      0.100      0.921      -6.466       7.160
# ar.L3         -0.3469      0.009    -40.503      0.000      -0.364      -0.330
# sigma2         0.0107    9.7e-05    109.854      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      129.46   Jarque-Bera (JB):             34650.73
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.58
# Prob(H) (two-sided):                  0.71   Kurtosis:                        19.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(4)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(4, 0)   Log Likelihood                2453.541
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4895.082
# Time:                        14:35:35   BIC                          -4859.289
# Sample:                    07-07-2020   HQIC                         -4882.181
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6960      0.607     48.911      0.000      28.506      30.886
# ar.L1.temperature     0.9976      0.019     53.547      0.000       0.961       1.034
# ar.L2.temperature     0.3474      0.026     13.612      0.000       0.297       0.397
# ar.L3.temperature    -0.3458      0.026    -13.550      0.000      -0.396      -0.296
# ar.L4.temperature    -0.0021      0.019     -0.112      0.911      -0.039       0.034
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7034           +0.0000j            1.7034            0.5000
# AR.2            1.0046           +0.0000j            1.0046            0.0000
# AR.3            1.6801           +0.0000j            1.6801            0.0000
# AR.4         -166.3869           +0.0000j          166.3869            0.5000
# -----------------------------------------------------------------------------
# AR(5)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(5, 0)   Log Likelihood                2459.753
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4905.507
# Time:                        14:35:36   BIC                          -4863.748
# Sample:                    07-07-2020   HQIC                         -4890.455
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6926      0.637     46.601      0.000      28.444      30.941
# ar.L1.temperature     0.9977      0.019     53.671      0.000       0.961       1.034
# ar.L2.temperature     0.3701      0.026     14.090      0.000       0.319       0.422
# ar.L3.temperature    -0.3686      0.026    -14.030      0.000      -0.420      -0.317
# ar.L4.temperature    -0.0676      0.026     -2.572      0.010      -0.119      -0.016
# ar.L5.temperature     0.0656      0.019      3.529      0.000       0.029       0.102
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.8265           -0.7419j            1.9714           -0.4386
# AR.2           -1.8265           +0.7419j            1.9714            0.4386
# AR.3            1.0040           -0.0000j            1.0040           -0.0000
# AR.4            1.8395           -0.7233j            1.9766           -0.0596
# AR.5            1.8395           +0.7233j            1.9766            0.0596
# -----------------------------------------------------------------------------

# %%
print("AR(1):  \t LL = ", results_t_ar_1.llf, "\t AIC = ", results_t_ar_1.aic)
print("AR(5):  \t LL = ", results_t_ar_5.llf, "\t AIC = ", results_t_ar_5.aic)
# Out:
# AR(1):  	 LL =  2262.7516816238985 	 AIC =  -4521.503363247797
# AR(5):  	 LL =  2459.7534280113045 	 AIC =  -4905.506856022609

# %%
print("\nLLR test AR(1)-AR(5) = " + str(LLR_test(results_t_ar_1, results_t_ar_2, DF = 4)))
# Out:
# LLR test AR(1)-AR(5) = 1.0

# %%
df_pred = results_t_ar_5.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.temperature[start_date:end_date].plot(color = "blue")
plt.title("Temperature AR: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 0.15630557177227003
# MSE 0.038332085027975485

# %% [markdown]
# ## MA

# %%
model_t_ma_1 = SARIMAX(df_train.temperature, order=(0,0,1))
results_t_ma_1 = model_t_ma_1.fit()
print(results_t_ma_1.summary())

model_t_ma_2 = ARIMA(df_train.temperature, order=(0,0,2))
results_t_ma_2 = model_t_ma_2.fit(start_ar_lags=100)
print(results_t_ma_2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(0, 0, 1)   Log Likelihood              -11873.840
# Date:                Mon, 20 Jul 2020   AIC                          23751.681
# Time:                        14:35:38   BIC                          23763.612
# Sample:                    07-07-2020   HQIC                         23755.981
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.9996      0.003    385.055      0.000       0.995       1.005
# sigma2       222.5976     51.777      4.299      0.000     121.116     324.079
# ===================================================================================
# Ljung-Box (Q):                    46904.29   Jarque-Bera (JB):               304.12
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             0.09
# Prob(H) (two-sided):                  0.12   Kurtosis:                         4.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(0, 2)   Log Likelihood               -2388.823
# Method:                       css-mle   S.D. of innovations              0.554
# Date:                Mon, 20 Jul 2020   AIC                           4785.647
# Time:                        14:35:38   BIC                           4809.509
# Sample:                    07-07-2020   HQIC                          4794.248
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.7295      0.035    853.782      0.000      29.661      29.798
# ma.L1.temperature     1.5087      0.011    131.425      0.000       1.486       1.531
# ma.L2.temperature     0.8640      0.007    115.636      0.000       0.849       0.879
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.8731           -0.6286j            1.0758           -0.4007
# MA.2           -0.8731           +0.6286j            1.0758            0.4007
# -----------------------------------------------------------------------------

# %%
print("MA(1):  \t LL = ", results_t_ma_1.llf, "\t AIC = ", results_t_ma_1.aic)
print("MA(2):  \t LL = ", results_t_ma_2.llf, "\t AIC = ", results_t_ma_2.aic)
# Out:
# MA(1):  	 LL =  -11873.840278133075 	 AIC =  23751.68055626615
# MA(2):  	 LL =  -2388.8233281780012 	 AIC =  4785.6466563560025

# %%
df_pred = results_t_ma_2.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.temperature[start_date:end_date].plot(color = "blue")
plt.title("Temperature MA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 0.3505330724475874
# MSE 0.15604456322360544

# %% [markdown]
# ## ARMA

# %%
print("\nARMA(1,1)") #NON SIGNIFICATIVO
results_t_ar_1_ma_1 = ARMA(df_train.temperature, order=(1,1)).fit()
print(results_t_ar_1_ma_1.summary())

print("\nARMA(2,1)") 
results_t_ar_2_ma_1 = ARMA(df_train.temperature, order=(2,1)).fit()
print(results_t_ar_2_ma_1.summary())

print("\nARMA(1,2)") #NON SIGNIFICATIVO
results_t_ar_1_ma_2 = ARMA(df_train.temperature, order=(1,2)).fit()
print(results_t_ar_1_ma_2.summary())

print("\nARMA(2,2)") #NON SIGNIFICATIVO
results_t_ar_2_ma_2 = ARMA(df_train.temperature, order=(2,2)).fit()
print(results_t_ar_2_ma_2.summary())

print("\nARMA(3,1)") #NON SIGNIFICATIVO
results_t_ar_3_ma_1 = ARMA(df_train.temperature, order=(3,1)).fit()
print(results_t_ar_3_ma_1.summary())

print("\nARMA(1,3)") #NON SIGNIFICATIVO
results_t_ar_1_ma_3 = ARMA(df_train.temperature, order=(1,3)).fit()
print(results_t_ar_1_ma_3.summary())

print("\nARMA(3,2)") #NON SIGNIFICATIVO
results_t_ar_3_ma_2 = ARMA(df_train.temperature, order=(3,2)).fit()
print(results_t_ar_3_ma_2.summary())

print("\nARMA(2,3)") 
results_t_ar_2_ma_3 = ARMA(df_train.temperature, order=(2,3)).fit()
print(results_t_ar_2_ma_3.summary())

print("\nARMA(3,3)") #NON SIGNIFICATIVO
results_t_ar_3_ma_3 = ARMA(df_train.temperature, order=(3,3)).fit()
print(results_t_ar_3_ma_3.summary())
# Out:
# ARMA(1,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(1, 1)   Log Likelihood                2267.647
# Method:                       css-mle   S.D. of innovations              0.110
# Date:                Mon, 20 Jul 2020   AIC                          -4527.293
# Time:                        14:35:40   BIC                          -4503.431
# Sample:                    07-07-2020   HQIC                         -4518.692
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6772      0.774     38.345      0.000      28.160      31.194
# ar.L1.temperature     0.9977      0.001    891.610      0.000       0.995       1.000
# ma.L1.temperature     0.0006      0.014      0.041      0.967      -0.028       0.029
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0023           +0.0000j            1.0023            0.0000
# MA.1        -1707.2499           +0.0000j         1707.2499            0.5000
# -----------------------------------------------------------------------------
#
# ARMA(2,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(2, 1)   Log Likelihood                2306.464
# Method:                       css-mle   S.D. of innovations              0.109
# Date:                Mon, 20 Jul 2020   AIC                          -4602.928
# Time:                        14:35:42   BIC                          -4573.100
# Sample:                    07-07-2020   HQIC                         -4592.176
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6999      0.595     49.906      0.000      28.534      30.866
# ar.L1.temperature     1.8004      0.040     45.436      0.000       1.723       1.878
# ar.L2.temperature    -0.8013      0.040    -20.281      0.000      -0.879      -0.724
# ma.L1.temperature    -0.7044      0.047    -14.929      0.000      -0.797      -0.612
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0048           +0.0000j            1.0048            0.0000
# AR.2            1.2420           +0.0000j            1.2420            0.0000
# MA.1            1.4196           +0.0000j            1.4196            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(1,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(1, 2)   Log Likelihood                2446.701
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4883.401
# Time:                        14:35:42   BIC                          -4853.574
# Sample:                    07-07-2020   HQIC                         -4872.650
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6884      0.672     44.151      0.000      28.370      31.006
# ar.L1.temperature     0.9965      0.001    697.894      0.000       0.994       0.999
# ma.L1.temperature     0.0011      0.018      0.062      0.950      -0.035       0.037
# ma.L2.temperature     0.3326      0.016     20.943      0.000       0.301       0.364
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0035           +0.0000j            1.0035            0.0000
# MA.1           -0.0017           -1.7340j            1.7340           -0.2502
# MA.2           -0.0017           +1.7340j            1.7340            0.2502
# -----------------------------------------------------------------------------
#
# ARMA(2,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(2, 2)   Log Likelihood                2446.708
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4881.416
# Time:                        14:35:44   BIC                          -4845.623
# Sample:                    07-07-2020   HQIC                         -4868.515
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6886      0.671     44.251      0.000      28.374      31.004
# ar.L1.temperature     1.0083      0.097     10.437      0.000       0.819       1.198
# ar.L2.temperature    -0.0118      0.096     -0.122      0.903      -0.201       0.177
# ma.L1.temperature    -0.0102      0.095     -0.108      0.914      -0.196       0.176
# ma.L2.temperature     0.3326      0.016     20.941      0.000       0.301       0.364
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0035           +0.0000j            1.0035            0.0000
# AR.2           84.8000           +0.0000j           84.8000            0.0000
# MA.1            0.0153           -1.7340j            1.7340           -0.2486
# MA.2            0.0153           +1.7340j            1.7340            0.2486
# -----------------------------------------------------------------------------
#
# ARMA(3,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(3, 1)   Log Likelihood                2453.539
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4895.079
# Time:                        14:35:45   BIC                          -4859.285
# Sample:                    07-07-2020   HQIC                         -4882.177
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6960      0.607     48.891      0.000      28.506      30.886
# ar.L1.temperature     1.0021      0.044     22.923      0.000       0.916       1.088
# ar.L2.temperature     0.3428      0.047      7.276      0.000       0.250       0.435
# ar.L3.temperature    -0.3479      0.017    -19.924      0.000      -0.382      -0.314
# ma.L1.temperature    -0.0044      0.046     -0.096      0.924      -0.094       0.085
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7012           +0.0000j            1.7012            0.5000
# AR.2            1.0046           +0.0000j            1.0046            0.0000
# AR.3            1.6821           +0.0000j            1.6821            0.0000
# MA.1          229.1661           +0.0000j          229.1661            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(1,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(1, 3)   Log Likelihood                2446.703
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4881.407
# Time:                        14:35:47   BIC                          -4845.613
# Sample:                    07-07-2020   HQIC                         -4868.505
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6885      0.672     44.187      0.000      28.372      31.005
# ar.L1.temperature     0.9965      0.001    695.212      0.000       0.994       0.999
# ma.L1.temperature     0.0013      0.018      0.070      0.944      -0.035       0.037
# ma.L2.temperature     0.3326      0.016     20.943      0.000       0.301       0.364
# ma.L3.temperature     0.0014      0.019      0.073      0.942      -0.036       0.039
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0035           +0.0000j            1.0035            0.0000
# MA.1            0.0044           -1.7340j            1.7340           -0.2496
# MA.2            0.0044           +1.7340j            1.7340            0.2496
# MA.3         -237.9657           -0.0000j          237.9657           -0.5000
# -----------------------------------------------------------------------------
#
# ARMA(3,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(3, 2)   Log Likelihood                2458.294
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4902.589
# Time:                        14:35:49   BIC                          -4860.830
# Sample:                    07-07-2020   HQIC                         -4887.537
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6938      0.627     47.394      0.000      28.466      30.922
# ar.L1.temperature     1.0027      0.052     19.177      0.000       0.900       1.105
# ar.L2.temperature     0.2204      0.069      3.199      0.001       0.085       0.355
# ar.L3.temperature    -0.2263      0.044     -5.086      0.000      -0.314      -0.139
# ma.L1.temperature    -0.0049      0.053     -0.092      0.927      -0.109       0.100
# ma.L2.temperature     0.1404      0.044      3.169      0.002       0.054       0.227
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1128           +0.0000j            2.1128            0.5000
# AR.2            1.0042           +0.0000j            1.0042            0.0000
# AR.3            2.0825           +0.0000j            2.0825            0.0000
# MA.1            0.0175           -2.6692j            2.6692           -0.2490
# MA.2            0.0175           +2.6692j            2.6692            0.2490
# -----------------------------------------------------------------------------
#
# ARMA(2,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(2, 3)   Log Likelihood                2465.436
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4916.872
# Time:                        14:35:55   BIC                          -4875.113
# Sample:                    07-07-2020   HQIC                         -4901.820
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.7311      0.313     94.954      0.000      29.117      30.345
# ar.L1.temperature     1.9855      0.004    549.985      0.000       1.978       1.993
# ar.L2.temperature    -0.9857      0.004   -274.163      0.000      -0.993      -0.979
# ma.L1.temperature    -0.9930      0.019    -53.400      0.000      -1.029      -0.957
# ma.L2.temperature     0.3363      0.024     14.080      0.000       0.289       0.383
# ma.L3.temperature    -0.3060      0.016    -18.848      0.000      -0.338      -0.274
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0071           -0.0133j            1.0072           -0.0021
# AR.2            1.0071           +0.0133j            1.0072            0.0021
# MA.1            1.0296           -0.0000j            1.0296           -0.0000
# MA.2            0.0346           -1.7811j            1.7814           -0.2469
# MA.3            0.0346           +1.7811j            1.7814            0.2469
# -----------------------------------------------------------------------------
#
# ARMA(3,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:                     ARMA(3, 3)   Log Likelihood                2458.295
# Method:                       css-mle   S.D. of innovations              0.103
# Date:                Mon, 20 Jul 2020   AIC                          -4900.591
# Time:                        14:36:01   BIC                          -4852.866
# Sample:                    07-07-2020   HQIC                         -4883.389
#                          - 07-17-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                29.6938      0.626     47.407      0.000      28.466      30.921
# ar.L1.temperature     1.0089      0.145      6.975      0.000       0.725       1.292
# ar.L2.temperature     0.2142      0.152      1.410      0.158      -0.083       0.512
# ar.L3.temperature    -0.2263      0.045     -5.084      0.000      -0.314      -0.139
# ma.L1.temperature    -0.0111      0.144     -0.077      0.939      -0.294       0.272
# ma.L2.temperature     0.1404      0.044      3.169      0.002       0.054       0.227
# ma.L3.temperature    -0.0026      0.055     -0.046      0.963      -0.111       0.106
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1268           +0.0000j            2.1268            0.5000
# AR.2            1.0042           +0.0000j            1.0042            0.0000
# AR.3            2.0691           +0.0000j            2.0691            0.0000
# MA.1           -0.0251           -2.6677j            2.6678           -0.2515
# MA.2           -0.0251           +2.6677j            2.6678            0.2515
# MA.3           55.0611           -0.0000j           55.0611           -0.0000
# -----------------------------------------------------------------------------

# %%
print("ARMA(2,1):  \t LL = ", results_t_ar_2_ma_1.llf, "\t AIC = ", results_t_ar_2_ma_1.aic)
print("ARMA(2,3):  \t LL = ", results_t_ar_2_ma_3.llf, "\t AIC = ", results_t_ar_2_ma_3.aic)
# Out:
# ARMA(2,1):  	 LL =  2306.4637564867467 	 AIC =  -4602.927512973493
# ARMA(2,3):  	 LL =  2465.435962845518 	 AIC =  -4916.871925691036

# %%
print("\nARMA(2,1) vs ARMA(2,3) ",LLR_test(results_t_ar_2_ma_1, results_t_ar_2_ma_3, DF=1))
# Out:
# ARMA(2,1) vs ARMA(2,3)  0.0

# %%
df_pred = results_t_ar_2_ma_3.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.temperature[start_date:end_date].plot(color = "blue")
plt.title("Temperature ARMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 0.12895144080272275
# MSE 0.02203024085270649

# %% [markdown]
# ## ARIMA

# %%
print("\nARIMA(1,1,1)") 
results_t_ar_1_i_1_ma_1 = SARIMAX(df_train.temperature, order=(1,1,1)).fit()
print(results_t_ar_1_i_1_ma_1.summary())

print("\nARIMA(2,1,1)")
results_t_ar_2_i_1_ma_1 = SARIMAX(df_train.temperature, order=(2,1,1)).fit()
print(results_t_ar_2_i_1_ma_1.summary())

print("\nARIMA(1,1,2)") #NON SIGNIFICATIVO
results_t_ar_1_i_1_ma_2 = SARIMAX(df_train.temperature, order=(1,1,2)).fit()
print(results_t_ar_1_i_1_ma_2.summary())

print("\nARIMA(1,1,3)") #NON SIGNIFICATIVO
results_t_ar_1_i_1_ma_3 = SARIMAX(df_train.temperature, order=(1,1,3)).fit()
print(results_t_ar_1_i_1_ma_3.summary())

print("\nARIMA(3,1,1)") 
results_t_ar_3_i_1_ma_1 = SARIMAX(df_train.temperature, order=(3,1,1)).fit()
print(results_t_ar_3_i_1_ma_1.summary())

print("\nARIMA(3,1,2)") #NON SIGNIFICATIVO
results_t_ar_3_i_1_ma_2 = SARIMAX(df_train.temperature, order=(3,1,2)).fit()
print(results_t_ar_3_i_1_ma_2.summary())

print("\nARIMA(3,1,3)") #NON SIGNIFICATIVO
results_t_ar_3_i_1_ma_3 = SARIMAX(df_train.temperature, order=(3,1,3)).fit()
print(results_t_ar_3_i_1_ma_3.summary())


############################

print("\nARIMA(1,2,1)")
results_t_ar_1_i_2_ma_1 = SARIMAX(df_train.temperature, order=(1,2,1)).fit()
print(results_t_ar_1_i_2_ma_1.summary())

print("\nARIMA(2,2,1)")
results_t_ar_2_i_2_ma_1 = SARIMAX(df_train.temperature, order=(2,2,1)).fit()
print(results_t_ar_2_i_2_ma_1.summary())

print("\nARIMA(1,2,2)") 
results_t_ar_1_i_2_ma_2 = SARIMAX(df_train.temperature, order=(1,2,2)).fit()
print(results_t_ar_1_i_2_ma_2.summary())

print("\nARIMA(2,2,2)") #NON SIGNIFICATIVO
results_t_ar_2_i_2_ma_2 = SARIMAX(df_train.temperature, order=(2,2,2)).fit()
print(results_t_ar_2_i_2_ma_2.summary())


print("\nARIMA(1,2,3)") #NON SIGNIFICATIVO
results_t_ar_1_i_2_ma_3 = SARIMAX(df_train.temperature, order=(1,2,3)).fit()
print(results_t_ar_1_i_2_ma_3.summary())

print("\nARIMA(3,2,1)") #NON SIGNIFICATIVO
results_t_ar_3_i_2_ma_1 = SARIMAX(df_train.temperature, order=(3,2,1)).fit()
print(results_t_ar_3_i_2_ma_1.summary())

print("\nARIMA(3,2,2)") #NON SIGNIFICATIVO
results_t_ar_3_i_2_ma_2 = SARIMAX(df_train.temperature, order=(3,2,2)).fit()
print(results_t_ar_3_i_2_ma_2.summary())

print("\nARIMA(3,2,3)") #NON SIGNIFICATIVO
results_t_ar_3_i_2_ma_3 = SARIMAX(df_train.temperature, order=(3,2,3)).fit()
print(results_t_ar_3_i_2_ma_3.summary())
# Out:
# ARIMA(1,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                2267.626
# Date:                Mon, 20 Jul 2020   AIC                          -4529.252
# Time:                        14:36:04   BIC                          -4511.356
# Sample:                    07-07-2020   HQIC                         -4522.802
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1        2.96e-08   2.39e-14   1.24e+06      0.000    2.96e-08    2.96e-08
# ma.L1      -5.013e-08   1.07e-14  -4.69e+06      0.000   -5.01e-08   -5.01e-08
# sigma2         0.0121      0.000    113.313      0.000       0.012       0.012
# ===================================================================================
# Ljung-Box (Q):                      703.76   Jarque-Bera (JB):             32211.58
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             2.08
# Prob(H) (two-sided):                  0.95   Kurtosis:                        18.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
#
# ARIMA(2,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                2451.975
# Date:                Mon, 20 Jul 2020   AIC                          -4895.951
# Time:                        14:36:05   BIC                          -4872.090
# Sample:                    07-07-2020   HQIC                         -4887.350
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       8.246e-09   2.14e-10     38.479      0.000    7.83e-09    8.67e-09
# ar.L2          0.3469      0.008     44.261      0.000       0.332       0.362
# ma.L1      -2.725e-08   3.12e-10    -87.400      0.000   -2.79e-08   -2.66e-08
# sigma2         0.0107    9.2e-05    115.843      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      129.50   Jarque-Bera (JB):             34695.05
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.59
# Prob(H) (two-sided):                  0.69   Kurtosis:                        19.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.46e+30. Standard errors may be unstable.
#
# ARIMA(1,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                2445.868
# Date:                Mon, 20 Jul 2020   AIC                          -4883.735
# Time:                        14:36:06   BIC                          -4859.874
# Sample:                    07-07-2020   HQIC                         -4875.134
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       7.769e-06   1439.298    5.4e-09      1.000   -2820.972    2820.972
# ma.L1      -1.266e-05   1043.092  -1.21e-08      1.000   -2044.424    2044.424
# ma.L2          0.3317      0.015     22.434      0.000       0.303       0.361
# sigma2         0.0107   9.42e-05    113.617      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      185.11   Jarque-Bera (JB):             33778.92
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.77
# Prob(H) (two-sided):                  0.73   Kurtosis:                        19.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 3)   Log Likelihood                2445.868
# Date:                Mon, 20 Jul 2020   AIC                          -4881.735
# Time:                        14:36:07   BIC                          -4851.909
# Sample:                    07-07-2020   HQIC                         -4870.984
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       1.313e-05    286.486   4.58e-08      1.000    -561.503     561.503
# ma.L1      -1.295e-05     76.199   -1.7e-07      1.000    -149.347     149.347
# ma.L2          0.3317      0.009     35.605      0.000       0.313       0.350
# ma.L3      -4.958e-06    738.911  -6.71e-09      1.000   -1448.239    1448.239
# sigma2         0.0107   9.39e-05    113.989      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      185.12   Jarque-Bera (JB):             33779.62
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.77
# Prob(H) (two-sided):                  0.73   Kurtosis:                        19.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.17e+19. Standard errors may be unstable.
#
# ARIMA(3,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 1)   Log Likelihood                2451.975
# Date:                Mon, 20 Jul 2020   AIC                          -4893.951
# Time:                        14:36:08   BIC                          -4864.125
# Sample:                    07-07-2020   HQIC                         -4883.200
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1      -7.901e-10   2.14e-10     -3.687      0.000   -1.21e-09    -3.7e-10
# ar.L2          0.3469      0.008     44.261      0.000       0.332       0.362
# ar.L3       2.605e-08    7.3e-11    356.954      0.000    2.59e-08    2.62e-08
# ma.L1      -2.725e-08   3.12e-10    -87.333      0.000   -2.79e-08   -2.66e-08
# sigma2         0.0107    9.2e-05    115.843      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      129.50   Jarque-Bera (JB):             34695.05
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.59
# Prob(H) (two-sided):                  0.69   Kurtosis:                        19.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.25e+31. Standard errors may be unstable.
#
# ARIMA(3,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 2)   Log Likelihood                2456.974
# Date:                Mon, 20 Jul 2020   AIC                          -4901.947
# Time:                        14:36:10   BIC                          -4866.156
# Sample:                    07-07-2020   HQIC                         -4889.046
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       4.795e-05    224.356   2.14e-07      1.000    -439.729     439.729
# ar.L2          0.2219      0.042      5.285      0.000       0.140       0.304
# ar.L3       1.497e-06    209.716   7.14e-09      1.000    -411.036     411.036
# ma.L1      -4.597e-05    218.895   -2.1e-07      1.000    -429.027     429.027
# ma.L2          0.1437      0.050      2.894      0.004       0.046       0.241
# sigma2         0.0106   9.27e-05    114.612      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      128.37   Jarque-Bera (JB):             34325.59
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.62
# Prob(H) (two-sided):                  0.69   Kurtosis:                        19.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.41e+16. Standard errors may be unstable.
#
# ARIMA(3,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 3)   Log Likelihood                2456.974
# Date:                Mon, 20 Jul 2020   AIC                          -4899.947
# Time:                        14:36:13   BIC                          -4858.191
# Sample:                    07-07-2020   HQIC                         -4884.896
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       5.149e-05   1893.011   2.72e-08      1.000   -3710.233    3710.233
# ar.L2          0.2219      0.127      1.741      0.082      -0.028       0.472
# ar.L3       3.816e-05    916.938   4.16e-08      1.000   -1797.166    1797.166
# ma.L1      -5.266e-05   1713.743  -3.07e-08      1.000   -3358.875    3358.875
# ma.L2          0.1437      0.107      1.340      0.180      -0.067       0.354
# ma.L3      -6.034e-05    353.208  -1.71e-07      1.000    -692.275     692.275
# sigma2         0.0106   9.33e-05    113.825      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      128.38   Jarque-Bera (JB):             34325.61
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.62
# Prob(H) (two-sided):                  0.69   Kurtosis:                        19.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.51e+14. Standard errors may be unstable.
#
# ARIMA(1,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 1)   Log Likelihood                2293.589
# Date:                Mon, 20 Jul 2020   AIC                          -4581.177
# Time:                        14:36:15   BIC                          -4563.283
# Sample:                    07-07-2020   HQIC                         -4574.727
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0622      0.053     -1.181      0.238      -0.165       0.041
# ma.L1         -0.9554      0.005   -184.431      0.000      -0.966      -0.945
# sigma2         0.0119      0.000    110.824      0.000       0.012       0.012
# ===================================================================================
# Ljung-Box (Q):                      531.49   Jarque-Bera (JB):             29934.83
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.80
# Prob(H) (two-sided):                  0.80   Kurtosis:                        18.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 1)   Log Likelihood                2443.300
# Date:                Mon, 20 Jul 2020   AIC                          -4878.599
# Time:                        14:36:16   BIC                          -4854.740
# Sample:                    07-07-2020   HQIC                         -4869.999
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0176      0.094     -0.186      0.852      -0.203       0.168
# ar.L2          0.3292      0.010     32.234      0.000       0.309       0.349
# ma.L1         -0.9822      0.005   -211.517      0.000      -0.991      -0.973
# sigma2         0.0107   9.33e-05    114.818      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      119.60   Jarque-Bera (JB):             33832.70
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.48
# Prob(H) (two-sided):                  0.64   Kurtosis:                        19.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 2)   Log Likelihood                2340.617
# Date:                Mon, 20 Jul 2020   AIC                          -4673.234
# Time:                        14:36:18   BIC                          -4649.375
# Sample:                    07-07-2020   HQIC                         -4664.634
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7555      0.069    -10.929      0.000      -0.891      -0.620
# ma.L1         -0.3235      0.077     -4.225      0.000      -0.474      -0.173
# ma.L2         -0.5979      0.081     -7.375      0.000      -0.757      -0.439
# sigma2         0.0115      0.000    104.223      0.000       0.011       0.012
# ===================================================================================
# Ljung-Box (Q):                      384.36   Jarque-Bera (JB):             30771.21
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.59
# Prob(H) (two-sided):                  0.65   Kurtosis:                        18.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 2)   Log Likelihood                2443.468
# Date:                Mon, 20 Jul 2020   AIC                          -4876.937
# Time:                        14:36:25   BIC                          -4847.112
# Sample:                    07-07-2020   HQIC                         -4866.186
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0438      0.274     -0.160      0.873      -0.580       0.493
# ar.L2          0.3273      0.011     30.704      0.000       0.306       0.348
# ma.L1         -0.9533      0.320     -2.978      0.003      -1.581      -0.326
# ma.L2         -0.0274      0.316     -0.087      0.931      -0.647       0.593
# sigma2         0.0107   9.46e-05    113.204      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      118.53   Jarque-Bera (JB):             33839.13
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.48
# Prob(H) (two-sided):                  0.63   Kurtosis:                        19.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 3)   Log Likelihood                2444.964
# Date:                Mon, 20 Jul 2020   AIC                          -4879.928
# Time:                        14:36:28   BIC                          -4850.104
# Sample:                    07-07-2020   HQIC                         -4869.178
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1587      0.124     -1.283      0.199      -0.401       0.084
# ma.L1         -0.8409      0.109     -7.733      0.000      -1.054      -0.628
# ma.L2          0.1848      0.106      1.749      0.080      -0.022       0.392
# ma.L3         -0.3040      0.015    -20.048      0.000      -0.334      -0.274
# sigma2         0.0107    9.4e-05    113.781      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      133.20   Jarque-Bera (JB):             32732.11
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.59
# Prob(H) (two-sided):                  0.62   Kurtosis:                        19.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 1)   Log Likelihood                2443.562
# Date:                Mon, 20 Jul 2020   AIC                          -4877.124
# Time:                        14:36:32   BIC                          -4847.300
# Sample:                    07-07-2020   HQIC                         -4866.374
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0149      0.121     -0.124      0.902      -0.252       0.222
# ar.L2          0.3270      0.011     30.728      0.000       0.306       0.348
# ar.L3         -0.0142      0.125     -0.113      0.910      -0.260       0.232
# ma.L1         -0.9806      0.005   -195.204      0.000      -0.990      -0.971
# sigma2         0.0107   9.32e-05    114.820      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      118.02   Jarque-Bera (JB):             33834.05
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.47
# Prob(H) (two-sided):                  0.63   Kurtosis:                        19.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 2)   Log Likelihood                2443.346
# Date:                Mon, 20 Jul 2020   AIC                          -4874.691
# Time:                        14:36:37   BIC                          -4838.902
# Sample:                    07-07-2020   HQIC                         -4861.791
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8727      1.635     -0.534      0.593      -4.077       2.332
# ar.L2          0.3138      0.103      3.046      0.002       0.112       0.516
# ar.L3          0.2839      0.519      0.547      0.584      -0.733       1.300
# ma.L1         -0.1285      1.611     -0.080      0.936      -3.286       3.029
# ma.L2         -0.8382      1.570     -0.534      0.593      -3.916       2.239
# sigma2         0.0107      0.000    106.788      0.000       0.011       0.011
# ===================================================================================
# Ljung-Box (Q):                      120.98   Jarque-Bera (JB):             33758.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                             1.48
# Prob(H) (two-sided):                  0.64   Kurtosis:                        19.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            temperature   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 3)   Log Likelihood                2451.225
# Date:                Mon, 20 Jul 2020   AIC                          -4888.451
# Time:                        14:36:45   BIC                          -4846.697
# Sample:                    07-07-2020   HQIC                         -4873.400
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6938      0.194     -3.582      0.000      -1.073      -0.314
# ar.L2          0.2053      0.197      1.043      0.297      -0.181       0.591
# ar.L3          0.2389      0.106      2.253      0.024       0.031       0.447
# ma.L1         -0.3011      0.147     -2.051      0.040      -0.589      -0.013
# ma.L2         -0.5347      0.229     -2.337      0.019      -0.983      -0.086
# ma.L3         -0.1586      0.216     -0.733      0.464      -0.583       0.265
# sigma2         0.0106   9.45e-05    112.629      0.000       0.010       0.011
# ===================================================================================
# Ljung-Box (Q):                      138.08   Jarque-Bera (JB):             33665.57
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             1.62
# Prob(H) (two-sided):                  0.71   Kurtosis:                        19.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print("ARMA(1,1,1):  \t LL = ", results_t_ar_1_i_1_ma_1.llf, "\t AIC = ", results_t_ar_1_i_1_ma_1.aic)
print("ARMA(2,1,1):  \t LL = ", results_t_ar_2_i_1_ma_1.llf, "\t AIC = ", results_t_ar_2_i_1_ma_1.aic)
print("ARMA(3,1,1):  \t LL = ", results_t_ar_3_i_1_ma_1.llf, "\t AIC = ", results_t_ar_3_i_1_ma_1.aic)
print("ARMA(1,2,1):  \t LL = ", results_t_ar_1_i_2_ma_1.llf, "\t AIC = ", results_t_ar_1_i_2_ma_1.aic)
print("ARMA(2,2,1):  \t LL = ", results_t_ar_2_i_2_ma_1.llf, "\t AIC = ", results_t_ar_2_i_2_ma_1.aic)
print("ARMA(1,2,2):  \t LL = ", results_t_ar_1_i_2_ma_2.llf, "\t AIC = ", results_t_ar_1_i_2_ma_2.aic)
# Out:
# ARMA(1,1,1):  	 LL =  2267.6259982388865 	 AIC =  -4529.251996477773
# ARMA(2,1,1):  	 LL =  2451.9753679003743 	 AIC =  -4895.950735800749
# ARMA(3,1,1):  	 LL =  2451.975367900289 	 AIC =  -4893.950735800578
# ARMA(1,2,1):  	 LL =  2293.588692069299 	 AIC =  -4581.177384138598
# ARMA(2,2,1):  	 LL =  2443.299510966861 	 AIC =  -4878.599021933722
# ARMA(1,2,2):  	 LL =  2340.6171085892283 	 AIC =  -4673.234217178457

# %%
df_pred = results_t_ar_2_i_1_ma_1.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.temperature[start_date:end_date].plot(color = "blue")
plt.title("Temperature ARIMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.temperature[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 0.17118556065618265
# MSE 0.0468448852866209
