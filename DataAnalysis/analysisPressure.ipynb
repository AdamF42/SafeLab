# %% [markdown]
# ## Importing the relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats.distributions import chi2 
from math import sqrt
import seaborn as sns
sns.set()
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from influxdb_client import InfluxDBClient

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the Data and Pre-processing

# %%
df = pd.read_csv("dataframe_11g_5m.csv")
df.time = pd.to_datetime(df.time, dayfirst = True)
df.set_index('time',inplace=True)
points_per_day = 288 
n_days = 11
df = df.drop(columns=['humidity', 'temperature', 'people'])
df
# Out:
#                            pressure
# time
# 2020-07-07 13:30:00+00:00    1019.5
# 2020-07-07 13:35:00+00:00    1019.5
# 2020-07-07 13:40:00+00:00    1019.5
# 2020-07-07 13:45:00+00:00    1019.5
# 2020-07-07 13:50:00+00:00    1019.5
# ...                             ...
# 2020-07-18 13:05:00+00:00    1018.4
# 2020-07-18 13:10:00+00:00    1018.4
# 2020-07-18 13:15:00+00:00    1018.4
# 2020-07-18 13:20:00+00:00    1018.4
# 2020-07-18 13:25:00+00:00    1018.4
#
# [3168 rows x 1 columns]

# %% [markdown]
# # Fill NaN values

# %%
df['pressure'] = df['pressure'].fillna(method='backfill').fillna(method='ffill')

# %%
points_per_day = int(len(df)/n_days) 
points_per_day
# Out:
# 288

# %%
print(df['pressure'].isnull().sum())
# Out:
# 0

# %% [markdown]
# # Split the dataset

# %%
# divide in train e test
#size = int(len(df)*0.8)
size = len(df)-points_per_day
df_train, df_test = df.iloc[:size], df.iloc[size:]

# %% [markdown]
# # Dickey–Fuller test

# %%
sts.adfuller(df.pressure) # non stazionaria
# Out:
# (-1.9304460578334657,
#  0.3178766249543116,
#  24,
#  3143,
#  {'1%': -3.432432293604288,
#   '5%': -2.862460029008544,
#   '10%': -2.5672597530168955},
#  -2794.548696586955)

# %% [markdown]
# ## The LLR Test

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.llf
    L2 = mod_2.llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %% [markdown]
# ## Auto Correlation Function (ACF)

# %%
sgt.plot_acf(df.pressure, zero = False, lags = 1000)
plt.title("ACF 4 pressure", size = 20)
plt.show()

# %% [markdown]
# ## Partial Auto Correlation Function (PACF)

# %%
sgt.plot_pacf(df.pressure, lags = 40, alpha = 0.05, zero = False, method = ('ols'))
plt.title("PACF 4 pressure", size = 20)
plt.show()

# %% [markdown]
# # Pressure

# %%
start_date = df_test.index[0]
end_date = df_test.index[points_per_day-1]

# %% [markdown]
# ## AR

# %%
print("AR(1)")
model_p_ar_1 = SARIMAX(df_train.pressure, order=(1,0,0))
results_p_ar_1 = model_p_ar_1.fit()
print(results_p_ar_1.summary())

print("AR(2)") 
model_p_ar_2 = SARIMAX(df_train.pressure, order=(2,0,0))
results_p_ar_2 = model_p_ar_2.fit()
print(results_p_ar_2.summary())

print("AR(3)") 
model_p_ar_3 = SARIMAX(df_train.pressure, order=(3,0,0))
results_p_ar_3 = model_p_ar_3.fit()
print(results_p_ar_3.summary())

print("AR(4)") #PARAMETRI NON SIGNIFICATIVI
model_p_ar_4 = ARIMA(df_train.pressure, order=(4,0,0))
results_p_ar_4 = model_p_ar_4.fit()
print(results_p_ar_4.summary())

print("AR(5)") #PARAMETRI NON SIGNIFICATIVI
model_p_ar_5 = ARIMA(df_train.pressure, order=(5,0,0))
results_p_ar_5 = model_p_ar_5.fit()
print(results_p_ar_5.summary())
# Out:
# AR(1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                1227.205
# Date:                Sun, 19 Jul 2020   AIC                          -2450.410
# Time:                        23:34:03   BIC                          -2438.479
# Sample:                    07-07-2020   HQIC                         -2446.110
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000   2.46e-08   4.07e+07      0.000       1.000       1.000
# sigma2         0.0249      0.000    242.573      0.000       0.025       0.025
# ===================================================================================
# Ljung-Box (Q):                       65.99   Jarque-Bera (JB):            814290.31
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                             2.05
# Prob(H) (two-sided):                  0.83   Kurtosis:                        85.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                1227.186
# Date:                Sun, 19 Jul 2020   AIC                          -2448.373
# Time:                        23:34:04   BIC                          -2430.476
# Sample:                    07-07-2020   HQIC                         -2441.922
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000   1.24e-08   8.04e+07      0.000       1.000       1.000
# ar.L2       4.507e-05   1.22e-08   3701.680      0.000     4.5e-05    4.51e-05
# sigma2         0.0249      0.000    242.570      0.000       0.025       0.025
# ===================================================================================
# Ljung-Box (Q):                       65.99   Jarque-Bera (JB):            814291.07
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                             2.05
# Prob(H) (two-sided):                  0.83   Kurtosis:                        85.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.18e+19. Standard errors may be unstable.
# AR(3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 0, 0)   Log Likelihood                1229.967
# Date:                Sun, 19 Jul 2020   AIC                          -2451.933
# Time:                        23:34:04   BIC                          -2428.071
# Sample:                    07-07-2020   HQIC                         -2443.332
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9999      0.008    132.955      0.000       0.985       1.015
# ar.L2         -0.0894      0.008    -11.873      0.000      -0.104      -0.075
# ar.L3          0.0894      0.015      5.943      0.000       0.060       0.119
# sigma2         0.0248      0.000    240.096      0.000       0.025       0.025
# ===================================================================================
# Ljung-Box (Q):                       51.49   Jarque-Bera (JB):            829288.54
# Prob(Q):                              0.11   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                             2.14
# Prob(H) (two-sided):                  0.99   Kurtosis:                        86.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.28e+16. Standard errors may be unstable.
# AR(4)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(4, 0)   Log Likelihood                1286.136
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2560.271
# Time:                        23:34:05   BIC                          -2524.478
# Sample:                    07-07-2020   HQIC                         -2547.369
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7776      1.502    678.387      0.000    1015.834    1021.721
# ar.L1.pressure     0.9992      0.019     53.687      0.000       0.963       1.036
# ar.L2.pressure    -0.0862      0.026     -3.280      0.001      -0.138      -0.035
# ar.L3.pressure     0.0861      0.026      3.275      0.001       0.035       0.138
# ar.L4.pressure    -0.0006      0.019     -0.034      0.973      -0.037       0.036
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2           -0.0394           -3.4173j            3.4176           -0.2518
# AR.3           -0.0394           +3.4173j            3.4176            0.2518
# AR.4          135.6924           -0.0000j          135.6924           -0.0000
# -----------------------------------------------------------------------------
# AR(5)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(5, 0)   Log Likelihood                1286.842
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2559.683
# Time:                        23:34:05   BIC                          -2517.924
# Sample:                    07-07-2020   HQIC                         -2544.631
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7876      1.484    686.506      0.000    1015.879    1021.696
# ar.L1.pressure     0.9992      0.019     53.696      0.000       0.963       1.036
# ar.L2.pressure    -0.0843      0.026     -3.202      0.001      -0.136      -0.033
# ar.L3.pressure     0.0842      0.026      3.197      0.001       0.033       0.136
# ar.L4.pressure     0.0215      0.026      0.816      0.414      -0.030       0.073
# ar.L5.pressure    -0.0221      0.019     -1.188      0.235      -0.059       0.014
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2           -2.9881           -0.0000j            2.9881           -0.5000
# AR.3           -0.0045           -2.2563j            2.2563           -0.2503
# AR.4           -0.0045           +2.2563j            2.2563            0.2503
# AR.5            2.9666           -0.0000j            2.9666           -0.0000
# -----------------------------------------------------------------------------

# %%
print("AR(1):  \t LL = ", results_p_ar_1.llf, "\t AIC = ", results_p_ar_1.aic)
print("AR(2):  \t LL = ", results_p_ar_2.llf, "\t AIC = ", results_p_ar_2.aic)
print("AR(3):  \t LL = ", results_p_ar_3.llf, "\t AIC = ", results_p_ar_3.aic)
# Out:
# AR(1):  	 LL =  1227.205051410468 	 AIC =  -2450.410102820936
# AR(2):  	 LL =  1227.1864564734665 	 AIC =  -2448.372912946933
# AR(3):  	 LL =  1229.9667090383314 	 AIC =  -2451.9334180766627

# %%
df_pred = results_p_ar_3.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.pressure[start_date:end_date].plot(color = "blue")
plt.title("Pressure AR: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 2.0753002891997676
# MSE 5.859209193738033

# %% [markdown]
# ## MA

# %%
model_p_ma_1 = ARMA(df_train.pressure, order=(0,1))
results_p_ma_1 = model_p_ma_1.fit()
print(results_p_ma_1.summary())

model_p_ma_2 = ARMA(df_train.pressure, order=(0,2))
results_p_ma_2 = model_p_ma_2.fit(start_ar_lags=100)
print(results_p_ma_2.summary())

model_p_ma_3 = ARMA(df_train.pressure, order=(0,3))
results_p_ma_3 = model_p_ma_3.fit()
print(results_p_ma_3.summary())

model_p_ma_4 = ARMA(df_train.pressure, order=(0,4))
results_p_ma_4 = model_p_ma_4.fit(start_ar_lags=100)
print(results_p_ma_4.summary())

model_p_ma_5 = ARMA(df_train.pressure, order=(0,5))
results_p_ma_5 = model_p_ma_5.fit()
print(results_p_ma_5.summary())

model_p_ma_6 = ARMA(df_train.pressure, order=(0,6))
results_p_ma_6 = model_p_ma_6.fit(start_ar_lags=100)
print(results_p_ma_6.summary())

model_p_ma_7 = ARMA(df_train.pressure, order=(0,7))
results_p_ma_7 = model_p_ma_7.fit()
print(results_p_ma_7.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 1)   Log Likelihood               -5166.174
# Method:                       css-mle   S.D. of innovations              1.454
# Date:                Sun, 19 Jul 2020   AIC                          10338.348
# Time:                        23:37:21   BIC                          10356.245
# Sample:                    07-07-2020   HQIC                         10344.799
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1449      0.053   1.92e+04      0.000    1019.041    1019.249
# ma.L1.pressure     0.9551      0.004    255.202      0.000       0.948       0.962
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.0470           +0.0000j            1.0470            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 2)   Log Likelihood               -3626.519
# Method:                       css-mle   S.D. of innovations              0.852
# Date:                Sun, 19 Jul 2020   AIC                           7261.038
# Time:                        23:37:21   BIC                           7284.900
# Sample:                    07-07-2020   HQIC                          7269.639
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1446      0.056   1.82e+04      0.000    1019.035    1019.255
# ma.L1.pressure     1.6636      0.009    184.568      0.000       1.646       1.681
# ma.L2.pressure     0.8731      0.007    125.834      0.000       0.859       0.887
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.9527           -0.4876j            1.0702           -0.4247
# MA.2           -0.9527           +0.4876j            1.0702            0.4247
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 3)   Log Likelihood               -2593.111
# Method:                       css-mle   S.D. of innovations              0.595
# Date:                Sun, 19 Jul 2020   AIC                           5196.223
# Time:                        23:37:22   BIC                           5226.051
# Sample:                    07-07-2020   HQIC                          5206.974
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1442      0.060    1.7e+04      0.000    1019.026    1019.262
# ma.L1.pressure     1.9305      0.021     91.398      0.000       1.889       1.972
# ma.L2.pressure     1.7602      0.018     98.387      0.000       1.725       1.795
# ma.L3.pressure     0.7287      0.012     63.298      0.000       0.706       0.751
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.1493           -0.0000j            1.1493           -0.5000
# MA.2           -0.6331           -0.8906j            1.0927           -0.3484
# MA.3           -0.6331           +0.8906j            1.0927            0.3484
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 4)   Log Likelihood               -1817.138
# Method:                       css-mle   S.D. of innovations              0.454
# Date:                Sun, 19 Jul 2020   AIC                           3646.275
# Time:                        23:37:22   BIC                           3682.068
# Sample:                    07-07-2020   HQIC                          3659.177
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1439      0.065   1.57e+04      0.000    1019.017    1019.271
# ma.L1.pressure     2.0252      0.019    107.738      0.000       1.988       2.062
# ma.L2.pressure     2.3207      0.028     84.130      0.000       2.267       2.375
# ma.L3.pressure     1.6767      0.019     86.633      0.000       1.639       1.715
# ma.L4.pressure     0.6537      0.013     50.415      0.000       0.628       0.679
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.2636           -1.0571j            1.0895           -0.2889
# MA.2           -0.2636           +1.0571j            1.0895            0.2889
# MA.3           -1.0188           -0.5009j            1.1352           -0.4273
# MA.4           -1.0188           +0.5009j            1.1352            0.4273
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 5)   Log Likelihood               -1301.937
# Method:                       css-mle   S.D. of innovations              0.380
# Date:                Sun, 19 Jul 2020   AIC                           2617.874
# Time:                        23:37:24   BIC                           2659.632
# Sample:                    07-07-2020   HQIC                          2632.925
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1435      0.070   1.46e+04      0.000    1019.006    1019.281
# ma.L1.pressure     2.0200      0.021     95.388      0.000       1.979       2.062
# ma.L2.pressure     2.5551      0.038     68.077      0.000       2.482       2.629
# ma.L3.pressure     2.3161      0.033     69.974      0.000       2.251       2.381
# ma.L4.pressure     1.4752      0.022     65.634      0.000       1.431       1.519
# ma.L5.pressure     0.5292      0.014     37.387      0.000       0.501       0.557
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            0.0142           -1.0853j            1.0854           -0.2479
# MA.2            0.0142           +1.0853j            1.0854            0.2479
# MA.3           -1.1960           -0.0000j            1.1960           -0.5000
# MA.4           -0.8100           -0.8276j            1.1580           -0.3733
# MA.5           -0.8100           +0.8276j            1.1580            0.3733
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 6)   Log Likelihood                -871.540
# Method:                       css-mle   S.D. of innovations              0.327
# Date:                Sun, 19 Jul 2020   AIC                           1759.080
# Time:                        23:37:27   BIC                           1806.804
# Sample:                    07-07-2020   HQIC                          1776.282
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1432      0.075   1.36e+04      0.000    1018.996    1019.290
# ma.L1.pressure     1.9626      0.020     98.839      0.000       1.924       2.002
# ma.L2.pressure     2.6288      0.038     68.315      0.000       2.553       2.704
# ma.L3.pressure     2.7115      0.044     62.202      0.000       2.626       2.797
# ma.L4.pressure     2.2053      0.034     65.468      0.000       2.139       2.271
# ma.L5.pressure     1.3309      0.025     54.047      0.000       1.283       1.379
# ma.L6.pressure     0.4964      0.015     32.996      0.000       0.467       0.526
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            0.2439           -1.0465j            1.0745           -0.2136
# MA.2            0.2439           +1.0465j            1.0745            0.2136
# MA.3           -1.0745           -0.4341j            1.1589           -0.4389
# MA.4           -1.0745           +0.4341j            1.1589            0.4389
# MA.5           -0.5099           -1.0194j            1.1398           -0.3238
# MA.6           -0.5099           +1.0194j            1.1398            0.3238
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(0, 7)   Log Likelihood                -579.807
# Method:                       css-mle   S.D. of innovations              0.296
# Date:                Sun, 19 Jul 2020   AIC                           1177.614
# Time:                        23:37:32   BIC                           1231.304
# Sample:                    07-07-2020   HQIC                          1196.966
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1019.1431      0.078    1.3e+04      0.000    1018.990    1019.296
# ma.L1.pressure     1.8513      0.020     91.572      0.000       1.812       1.891
# ma.L2.pressure     2.4768      0.037     66.400      0.000       2.404       2.550
# ma.L3.pressure     2.7411      0.045     60.366      0.000       2.652       2.830
# ma.L4.pressure     2.5554      0.041     62.131      0.000       2.475       2.636
# ma.L5.pressure     1.9577      0.033     59.940      0.000       1.894       2.022
# ma.L6.pressure     1.1787      0.025     47.710      0.000       1.130       1.227
# ma.L7.pressure     0.4411      0.015     28.607      0.000       0.411       0.471
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            0.4255           -0.9690j            1.0583           -0.1842
# MA.2            0.4255           +0.9690j            1.0583            0.1842
# MA.3           -0.2548           -1.1020j            1.1311           -0.2862
# MA.4           -0.2548           +1.1020j            1.1311            0.2862
# MA.5           -1.1870           -0.0000j            1.1870           -0.5000
# MA.6           -0.9132           -0.7063j            1.1545           -0.3952
# MA.7           -0.9132           +0.7063j            1.1545            0.3952
# -----------------------------------------------------------------------------

# %%
print("MA(1):  \t LL = ", results_p_ma_1.llf, "\t AIC = ", results_p_ma_1.aic)
print("MA(2):  \t LL = ", results_p_ma_2.llf, "\t AIC = ", results_p_ma_2.aic)
print("MA(3):  \t LL = ", results_p_ma_3.llf, "\t AIC = ", results_p_ma_3.aic)
print("MA(4):  \t LL = ", results_p_ma_4.llf, "\t AIC = ", results_p_ma_4.aic)
print("MA(5):  \t LL = ", results_p_ma_5.llf, "\t AIC = ", results_p_ma_5.aic)
print("MA(6):  \t LL = ", results_p_ma_6.llf, "\t AIC = ", results_p_ma_6.aic)
print("MA(7):  \t LL = ", results_p_ma_7.llf, "\t AIC = ", results_p_ma_7.aic)
# Out:
# MA(1):  	 LL =  -5166.174176296827 	 AIC =  10338.348352593654
# MA(2):  	 LL =  -3626.5187987258514 	 AIC =  7261.037597451703
# MA(3):  	 LL =  -2593.1114668634655 	 AIC =  5196.222933726931
# MA(4):  	 LL =  -1817.1375615894017 	 AIC =  3646.2751231788034
# MA(5):  	 LL =  -1301.93676078121 	 AIC =  2617.87352156242
# MA(6):  	 LL =  -871.5399890255239 	 AIC =  1759.0799780510479
# MA(7):  	 LL =  -579.8068300828199 	 AIC =  1177.6136601656399

# %%
df_pred = results_p_ma_7.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.pressure[start_date:end_date].plot(color = "blue")
plt.title("Pressure MA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 1.0010934519130064
# MSE 1.8247636231863023

# %% [markdown]
# ## ARMA

# %%
print("\nARMA(1,1)") #NON SIGNIFICATIVO
results_p_ar_1_ma_1 = ARMA(df_train.pressure, order=(1,1)).fit()
print(results_p_ar_1_ma_1.summary())

print("\nARMA(2,1)") 
results_p_ar_2_ma_1 = ARMA(df_train.pressure, order=(2,1)).fit()
print(results_p_ar_2_ma_1.summary())

print("\nARMA(1,2)") #NON SIGNIFICATIVO
results_p_ar_1_ma_2 = ARMA(df_train.pressure, order=(1,2)).fit()
print(results_p_ar_1_ma_2.summary())

print("\nARMA(2,2)") #NON SIGNIFICATIVO
results_p_ar_2_ma_2 = ARMA(df_train.pressure, order=(2,2)).fit()
print(results_p_ar_2_ma_2.summary())

print("\nARMA(3,1)") #NON SIGNIFICATIVO
results_p_ar_3_ma_1 = ARMA(df_train.pressure, order=(3,1)).fit()
print(results_p_ar_3_ma_1.summary())

print("\nARMA(1,3)") #NON SIGNIFICATIVO
results_p_ar_1_ma_3 = ARMA(df_train.pressure, order=(1,3)).fit()
print(results_p_ar_1_ma_3.summary())

print("\nARMA(3,2)") #NON SIGNIFICATIVO
results_p_ar_3_ma_2 = ARMA(df_train.pressure, order=(3,2)).fit()
print(results_p_ar_3_ma_2.summary())

print("\nARMA(2,3)") 
results_p_ar_2_ma_3 = ARMA(df_train.pressure, order=(2,3)).fit()
print(results_p_ar_2_ma_3.summary())

print("\nARMA(3,3)") #NON SIGNIFICATIVO
results_p_ar_3_ma_3 = ARMA(df_train.pressure, order=(3,3)).fit()
print(results_p_ar_3_ma_3.summary())
# Out:
# ARMA(1,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(1, 1)   Log Likelihood                1275.576
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2543.152
# Time:                        23:38:59   BIC                          -2519.290
# Sample:                    07-07-2020   HQIC                         -2534.551
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.8154      1.432    711.258      0.000    1016.008    1021.623
# ar.L1.pressure     0.9983      0.001   1045.769      0.000       0.996       1.000
# ma.L1.pressure     0.0009      0.021      0.044      0.965      -0.039       0.041
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# MA.1        -1098.1522           +0.0000j         1098.1522            0.5000
# -----------------------------------------------------------------------------
#
# ARMA(2,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(2, 1)   Log Likelihood                1277.491
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2544.983
# Time:                        23:39:00   BIC                          -2515.155
# Sample:                    07-07-2020   HQIC                         -2534.232
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.8228      1.418    718.489      0.000    1016.044    1021.602
# ar.L1.pressure     0.4281      0.168      2.552      0.011       0.099       0.757
# ar.L2.pressure     0.5691      0.168      3.397      0.001       0.241       0.897
# ma.L1.pressure     0.6001      0.163      3.685      0.000       0.281       0.919
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0018           +0.0000j            1.0018            0.0000
# AR.2           -1.7541           +0.0000j            1.7541            0.5000
# MA.1           -1.6664           +0.0000j            1.6664            0.5000
# -----------------------------------------------------------------------------
#
# ARMA(1,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(1, 2)   Log Likelihood                1285.594
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2561.188
# Time:                        23:39:00   BIC                          -2531.360
# Sample:                    07-07-2020   HQIC                         -2550.436
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7762      1.504    677.418      0.000    1015.829    1021.724
# ar.L1.pressure     0.9985      0.001   1155.093      0.000       0.997       1.000
# ma.L1.pressure     0.0007      0.019      0.036      0.971      -0.036       0.037
# ma.L2.pressure    -0.0811      0.018     -4.505      0.000      -0.116      -0.046
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           +0.0000j            1.0015            0.0000
# MA.1           -3.5069           +0.0000j            3.5069            0.5000
# MA.2            3.5152           +0.0000j            3.5152            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(2,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(2, 2)   Log Likelihood                1285.594
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2559.188
# Time:                        23:39:01   BIC                          -2523.395
# Sample:                    07-07-2020   HQIC                         -2546.287
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7764      1.504    677.528      0.000    1015.829    1021.724
# ar.L1.pressure     0.9946      0.154      6.445      0.000       0.692       1.297
# ar.L2.pressure     0.0040      0.154      0.026      0.979      -0.298       0.306
# ma.L1.pressure     0.0046      0.154      0.030      0.976      -0.296       0.306
# ma.L2.pressure    -0.0811      0.018     -4.504      0.000      -0.116      -0.046
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           +0.0000j            1.0015            0.0000
# AR.2         -251.7421           +0.0000j          251.7421            0.5000
# MA.1           -3.4828           +0.0000j            3.4828            0.5000
# MA.2            3.5395           +0.0000j            3.5395            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(3,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(3, 1)   Log Likelihood                1286.135
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2560.271
# Time:                        23:39:02   BIC                          -2524.477
# Sample:                    07-07-2020   HQIC                         -2547.369
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7774      1.502    678.337      0.000    1015.834    1021.721
# ar.L1.pressure     0.9943      0.163      6.093      0.000       0.674       1.314
# ar.L2.pressure    -0.0813      0.164     -0.496      0.620      -0.403       0.240
# ar.L3.pressure     0.0854      0.019      4.603      0.000       0.049       0.122
# ma.L1.pressure     0.0049      0.164      0.030      0.976      -0.316       0.326
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2           -0.0248           -3.4185j            3.4186           -0.2512
# AR.3           -0.0248           +3.4185j            3.4186            0.2512
# MA.1         -205.8732           +0.0000j          205.8732            0.5000
# -----------------------------------------------------------------------------
#
# ARMA(1,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(1, 3)   Log Likelihood                1285.594
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2559.189
# Time:                        23:39:03   BIC                          -2523.395
# Sample:                    07-07-2020   HQIC                         -2546.287
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7765      1.504    677.594      0.000    1015.830    1021.723
# ar.L1.pressure     0.9985      0.001   1152.806      0.000       0.997       1.000
# ma.L1.pressure     0.0006      0.019      0.032      0.975      -0.036       0.037
# ma.L2.pressure    -0.0811      0.018     -4.505      0.000      -0.116      -0.046
# ma.L3.pressure     0.0006      0.018      0.031      0.975      -0.036       0.037
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           +0.0000j            1.0015            0.0000
# MA.1           -3.4656           +0.0000j            3.4656            0.5000
# MA.2            3.5594           +0.0000j            3.5594            0.0000
# MA.3          142.5240           +0.0000j          142.5240            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(3,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(3, 2)   Log Likelihood                1286.690
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2559.380
# Time:                        23:39:04   BIC                          -2517.621
# Sample:                    07-07-2020   HQIC                         -2544.328
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7838      1.491    683.397      0.000    1015.862    1021.706
# ar.L1.pressure     0.9932      0.193      5.150      0.000       0.615       1.371
# ar.L2.pressure    -0.2829      0.269     -1.053      0.292      -0.810       0.244
# ar.L3.pressure     0.2878      0.188      1.532      0.125      -0.080       0.656
# ma.L1.pressure     0.0059      0.197      0.030      0.976      -0.381       0.393
# ma.L2.pressure     0.2039      0.192      1.060      0.289      -0.173       0.581
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2           -0.0092           -1.8627j            1.8628           -0.2508
# AR.3           -0.0092           +1.8627j            1.8628            0.2508
# MA.1           -0.0145           -2.2148j            2.2148           -0.2510
# MA.2           -0.0145           +2.2148j            2.2148            0.2510
# -----------------------------------------------------------------------------
#
# ARMA(2,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(2, 3)   Log Likelihood                1290.892
# Method:                       css-mle   S.D. of innovations              0.154
# Date:                Sun, 19 Jul 2020   AIC                          -2567.785
# Time:                        23:39:08   BIC                          -2526.026
# Sample:                    07-07-2020   HQIC                         -2552.733
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.8670      1.062    959.460      0.000    1016.786    1020.948
# ar.L1.pressure     1.9871      0.000   8649.480      0.000       1.987       1.988
# ar.L2.pressure    -0.9872      0.000  -4307.165      0.000      -0.988      -0.987
# ma.L1.pressure    -0.9928      0.019    -53.599      0.000      -1.029      -0.956
# ma.L2.pressure    -0.0813      0.026     -3.182      0.001      -0.131      -0.031
# ma.L3.pressure     0.0928      0.018      5.081      0.000       0.057       0.129
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0065           -0.0025j            1.0065           -0.0004
# AR.2            1.0065           +0.0025j            1.0065            0.0004
# MA.1            1.0214           +0.0000j            1.0214            0.0000
# MA.2           -3.3215           +0.0000j            3.3215            0.5000
# MA.3            3.1765           +0.0000j            3.1765            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(3,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:                     ARMA(3, 3)   Log Likelihood                1286.691
# Method:                       css-mle   S.D. of innovations              0.155
# Date:                Sun, 19 Jul 2020   AIC                          -2557.382
# Time:                        23:39:09   BIC                          -2509.657
# Sample:                    07-07-2020   HQIC                         -2540.180
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1018.7841      1.490    683.641      0.000    1015.863    1021.705
# ar.L1.pressure     1.0229      0.494      2.071      0.038       0.055       1.991
# ar.L2.pressure    -0.3124      0.522     -0.598      0.550      -1.336       0.711
# ar.L3.pressure     0.2876      0.188      1.531      0.126      -0.081       0.656
# ma.L1.pressure    -0.0238      0.495     -0.048      0.962      -0.993       0.946
# ma.L2.pressure     0.2037      0.192      1.059      0.289      -0.173       0.581
# ma.L3.pressure     0.0028      0.048      0.059      0.953      -0.090       0.096
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2            0.0424           -1.8628j            1.8633           -0.2464
# AR.3            0.0424           +1.8628j            1.8633            0.2464
# MA.1            0.0918           -2.2111j            2.2130           -0.2434
# MA.2            0.0918           +2.2111j            2.2130            0.2434
# MA.3          -72.8611           -0.0000j           72.8611           -0.5000
# -----------------------------------------------------------------------------

# %%
print("ARMA(2,1):  \t LL = ", results_p_ar_2_ma_1.llf, "\t AIC = ", results_p_ar_2_ma_1.aic)
print("ARMA(2,3):  \t LL = ", results_p_ar_2_ma_3.llf, "\t AIC = ", results_p_ar_2_ma_3.aic)
# Out:
# ARMA(2,1):  	 LL =  1277.4914938408688 	 AIC =  -2544.9829876817375
# ARMA(2,3):  	 LL =  1290.8924215210095 	 AIC =  -2567.784843042019

# %%
print("\nARMA(2,1) vs ARMA(2,3) ",LLR_test(results_p_ar_2_ma_1, results_p_ar_2_ma_3, DF=1))
# Out:
# ARMA(2,1) vs ARMA(2,3)  0.0

# %%
df_pred = results_p_ar_2_ma_3.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.pressure[start_date:end_date].plot(color = "blue")
plt.title("Pressure ARMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 1.1598959633583397
# MSE 2.062503927096005

# %% [markdown]
# ## ARIMA

# %%
print("\nARIMA(1,1,1)") 
results_p_ar_1_i_1_ma_1 = SARIMAX(df_train.pressure, order=(1,1,1)).fit()
print(results_p_ar_1_i_1_ma_1.summary())

print("\nARIMA(2,1,1)")
results_p_ar_2_i_1_ma_1 = SARIMAX(df_train.pressure, order=(2,1,1)).fit()
print(results_p_ar_2_i_1_ma_1.summary())

print("\nARIMA(1,1,2)") #NON SIGNIFICATIVO
results_p_ar_1_i_1_ma_2 = SARIMAX(df_train.pressure, order=(1,1,2)).fit()
print(results_p_ar_1_i_1_ma_2.summary())

print("\nARIMA(1,1,3)") #NON SIGNIFICATIVO
results_p_ar_1_i_1_ma_3 = SARIMAX(df_train.pressure, order=(1,1,3)).fit()
print(results_p_ar_1_i_1_ma_3.summary())

print("\nARIMA(3,1,1)") 
results_p_ar_3_i_1_ma_1 = SARIMAX(df_train.pressure, order=(3,1,1)).fit()
print(results_p_ar_3_i_1_ma_1.summary())

print("\nARIMA(3,1,2)") #NON SIGNIFICATIVO
results_p_ar_3_i_1_ma_2 = SARIMAX(df_train.pressure, order=(3,1,2)).fit()
print(results_p_ar_3_i_1_ma_2.summary())

print("\nARIMA(3,1,3)") #NON SIGNIFICATIVO
results_p_ar_3_i_1_ma_3 = SARIMAX(df_train.pressure, order=(3,1,3)).fit()
print(results_p_ar_3_i_1_ma_3.summary())


############################

print("\nARIMA(1,2,1)")
results_p_ar_1_i_2_ma_1 = SARIMAX(df_train.pressure, order=(1,2,1)).fit()
print(results_p_ar_1_i_2_ma_1.summary())

print("\nARIMA(2,2,1)")
results_p_ar_2_i_2_ma_1 = SARIMAX(df_train.pressure, order=(2,2,1)).fit()
print(results_p_ar_2_i_2_ma_1.summary())

print("\nARIMA(1,2,2)") #NON SIGNIFICATIVO
results_p_ar_1_i_2_ma_2 = SARIMAX(df_train.pressure, order=(1,2,2)).fit()
print(results_p_ar_1_i_2_ma_2.summary())

print("\nARIMA(2,2,2)") #NON SIGNIFICATIVO
results_p_ar_2_i_2_ma_2 = SARIMAX(df_train.pressure, order=(2,2,2)).fit()
print(results_p_ar_2_i_2_ma_2.summary())


print("\nARIMA(1,2,3)") #NON SIGNIFICATIVO
results_p_ar_1_i_2_ma_3 = SARIMAX(df_train.pressure, order=(1,2,3)).fit()
print(results_p_ar_1_i_2_ma_3.summary())

print("\nARIMA(3,2,1)") #NON SIGNIFICATIVO
results_p_ar_3_i_2_ma_1 = SARIMAX(df_train.pressure, order=(3,2,1)).fit()
print(results_p_ar_3_i_2_ma_1.summary())

print("\nARIMA(3,2,2)") #NON SIGNIFICATIVO
results_p_ar_3_i_2_ma_2 = SARIMAX(df_train.pressure, order=(3,2,2)).fit()
print(results_p_ar_3_i_2_ma_2.summary())

print("\nARIMA(3,2,3)") #NON SIGNIFICATIVO
results_p_ar_3_i_2_ma_3 = SARIMAX(df_train.pressure, order=(3,2,3)).fit()
print(results_p_ar_3_i_2_ma_3.summary())
# Out:
# ARIMA(1,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                1276.593
# Date:                Sun, 19 Jul 2020   AIC                          -2547.186
# Time:                        23:40:00   BIC                          -2529.291
# Sample:                    07-07-2020   HQIC                         -2540.736
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       5.917e-08   4.34e-14   1.36e+06      0.000    5.92e-08    5.92e-08
# ma.L1      -4.896e-08   4.43e-14   -1.1e+06      0.000    -4.9e-08    -4.9e-08
# sigma2         0.0241   9.65e-05    249.976      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       70.03   Jarque-Bera (JB):            865728.12
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             1.86
# Prob(H) (two-sided):                  0.06   Kurtosis:                        87.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
#
# ARIMA(2,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                1287.323
# Date:                Sun, 19 Jul 2020   AIC                          -2566.646
# Time:                        23:40:00   BIC                          -2542.785
# Sample:                    07-07-2020   HQIC                         -2558.045
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       7.591e-08   8.72e-10     87.078      0.000    7.42e-08    7.76e-08
# ar.L2         -0.0862      0.015     -5.855      0.000      -0.115      -0.057
# ma.L1      -5.902e-08    5.9e-10   -100.075      0.000   -6.02e-08   -5.79e-08
# sigma2         0.0239   9.62e-05    248.809      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       54.85   Jarque-Bera (JB):            880538.40
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.89
# Prob(H) (two-sided):                  0.05   Kurtosis:                        88.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.33e+30. Standard errors may be unstable.
#
# ARIMA(1,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                1286.786
# Date:                Sun, 19 Jul 2020   AIC                          -2565.572
# Time:                        23:40:00   BIC                          -2541.711
# Sample:                    07-07-2020   HQIC                         -2556.971
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       5.654e-06   1113.330   5.08e-09      1.000   -2182.087    2182.087
# ma.L1      -4.776e-06   1121.704  -4.26e-09      1.000   -2198.499    2198.499
# ma.L2         -0.0818      0.018     -4.509      0.000      -0.117      -0.046
# sigma2         0.0239   9.61e-05    249.098      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       56.19   Jarque-Bera (JB):            880441.37
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             1.89
# Prob(H) (two-sided):                  0.05   Kurtosis:                        88.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.43e+21. Standard errors may be unstable.
#
# ARIMA(1,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 3)   Log Likelihood                1286.786
# Date:                Sun, 19 Jul 2020   AIC                          -2563.572
# Time:                        23:40:01   BIC                          -2533.746
# Sample:                    07-07-2020   HQIC                         -2552.821
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       6.299e-06    494.639   1.27e-08      1.000    -969.474     969.474
# ma.L1      -5.144e-06    641.333  -8.02e-09      1.000   -1256.989    1256.989
# ma.L2         -0.0818      0.016     -5.079      0.000      -0.113      -0.050
# ma.L3      -4.743e-06    410.558  -1.16e-08      1.000    -804.678     804.678
# sigma2         0.0239   9.63e-05    248.581      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       56.19   Jarque-Bera (JB):            880441.53
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             1.89
# Prob(H) (two-sided):                  0.05   Kurtosis:                        88.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.05e+16. Standard errors may be unstable.
#
# ARIMA(3,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 1)   Log Likelihood                1287.323
# Date:                Sun, 19 Jul 2020   AIC                          -2564.646
# Time:                        23:40:02   BIC                          -2534.820
# Sample:                    07-07-2020   HQIC                         -2553.895
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       8.099e-08   8.72e-10     92.897      0.000    7.93e-08    8.27e-08
# ar.L2         -0.0862      0.015     -5.855      0.000      -0.115      -0.057
# ar.L3       5.886e-08   1.84e-10    319.877      0.000    5.85e-08    5.92e-08
# ma.L1      -5.902e-08   7.08e-10    -83.355      0.000   -6.04e-08   -5.76e-08
# sigma2         0.0239   9.62e-05    248.809      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       54.85   Jarque-Bera (JB):            880538.40
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.89
# Prob(H) (two-sided):                  0.05   Kurtosis:                        88.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.1e+31. Standard errors may be unstable.
#
# ARIMA(3,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 2)   Log Likelihood                1287.852
# Date:                Sun, 19 Jul 2020   AIC                          -2563.703
# Time:                        23:40:02   BIC                          -2527.912
# Sample:                    07-07-2020   HQIC                         -2550.802
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       3.062e-07   1.77e-07      1.725      0.085   -4.17e-08    6.54e-07
# ar.L2         -0.2803      0.146     -1.922      0.055      -0.566       0.005
# ar.L3       1.195e-07   7.48e-07      0.160      0.873   -1.35e-06    1.59e-06
# ma.L1      -2.137e-07   3.78e-07     -0.566      0.572   -9.54e-07    5.27e-07
# ma.L2          0.1956      0.151      1.297      0.195      -0.100       0.491
# sigma2         0.0239   9.62e-05    248.646      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       52.45   Jarque-Bera (JB):            880742.76
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.89
# Prob(H) (two-sided):                  0.04   Kurtosis:                        88.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.03e+28. Standard errors may be unstable.
#
# ARIMA(3,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 3)   Log Likelihood                1287.852
# Date:                Sun, 19 Jul 2020   AIC                          -2561.704
# Time:                        23:40:04   BIC                          -2519.947
# Sample:                    07-07-2020   HQIC                         -2546.652
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0026    957.653   2.69e-06      1.000   -1876.962    1876.967
# ar.L2         -0.2834      1.036     -0.273      0.784      -2.314       1.747
# ar.L3          0.0013    319.022   4.16e-06      1.000    -625.271     625.273
# ma.L1         -0.0024    956.184   -2.5e-06      1.000   -1874.089    1874.084
# ma.L2          0.1984      1.196      0.166      0.868      -2.145       2.542
# ma.L3         -0.0011    213.149  -5.28e-06      1.000    -417.766     417.764
# sigma2         0.0239   9.73e-05    245.946      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       52.46   Jarque-Bera (JB):            880686.16
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.89
# Prob(H) (two-sided):                  0.04   Kurtosis:                        88.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 1)   Log Likelihood                1271.732
# Date:                Sun, 19 Jul 2020   AIC                          -2537.464
# Time:                        23:40:05   BIC                          -2519.569
# Sample:                    07-07-2020   HQIC                         -2531.014
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0004      0.589      0.001      1.000      -1.153       1.154
# ma.L1         -1.0000      0.079    -12.643      0.000      -1.155      -0.845
# sigma2         0.0241      0.002     13.039      0.000       0.020       0.028
# ===================================================================================
# Ljung-Box (Q):                       69.97   Jarque-Bera (JB):            861416.35
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             1.87
# Prob(H) (two-sided):                  0.06   Kurtosis:                        87.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 1)   Log Likelihood                1283.054
# Date:                Sun, 19 Jul 2020   AIC                          -2558.109
# Time:                        23:40:06   BIC                          -2534.249
# Sample:                    07-07-2020   HQIC                         -2549.509
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0049      0.184     -0.027      0.979      -0.366       0.356
# ar.L2         -0.0910      0.015     -5.946      0.000      -0.121      -0.061
# ma.L1         -0.9935      0.003   -382.425      0.000      -0.999      -0.988
# sigma2         0.0240      0.000    200.568      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       46.28   Jarque-Bera (JB):            839445.09
# Prob(Q):                              0.23   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.85
# Prob(H) (two-sided):                  0.05   Kurtosis:                        86.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 2)   Log Likelihood                1273.623
# Date:                Sun, 19 Jul 2020   AIC                          -2539.246
# Time:                        23:40:08   BIC                          -2515.386
# Sample:                    07-07-2020   HQIC                         -2530.645
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5718      0.477     -1.198      0.231      -1.507       0.364
# ma.L1         -0.3982      0.452     -0.880      0.379      -1.285       0.488
# ma.L2         -0.6017      0.454     -1.325      0.185      -1.492       0.288
# sigma2         0.0241      0.000     67.498      0.000       0.023       0.025
# ===================================================================================
# Ljung-Box (Q):                       67.87   Jarque-Bera (JB):            864257.14
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             1.88
# Prob(H) (two-sided):                  0.06   Kurtosis:                        87.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 2)   Log Likelihood                1283.086
# Date:                Sun, 19 Jul 2020   AIC                          -2556.172
# Time:                        23:40:11   BIC                          -2526.347
# Sample:                    07-07-2020   HQIC                         -2545.421
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0397      1.268      0.031      0.975      -2.446       2.525
# ar.L2         -0.0910      0.018     -5.132      0.000      -0.126      -0.056
# ma.L1         -1.0384      1.230     -0.844      0.399      -3.450       1.373
# ma.L2          0.0448      1.222      0.037      0.971      -2.351       2.440
# sigma2         0.0240      0.000    200.147      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       45.93   Jarque-Bera (JB):            838681.93
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.85
# Prob(H) (two-sided):                  0.05   Kurtosis:                        86.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 3)   Log Likelihood                1282.609
# Date:                Sun, 19 Jul 2020   AIC                          -2555.218
# Time:                        23:40:15   BIC                          -2525.394
# Sample:                    07-07-2020   HQIC                         -2544.468
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0383      1.302      0.029      0.977      -2.515       2.591
# ma.L1         -1.0372      1.247     -0.832      0.406      -3.481       1.407
# ma.L2         -0.0437      1.244     -0.035      0.972      -2.482       2.395
# ma.L3          0.0869      0.019      4.679      0.000       0.050       0.123
# sigma2         0.0240      0.000    200.788      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       46.99   Jarque-Bera (JB):            837908.62
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.85
# Prob(H) (two-sided):                  0.05   Kurtosis:                        86.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 1)   Log Likelihood                1283.097
# Date:                Sun, 19 Jul 2020   AIC                          -2556.194
# Time:                        23:40:16   BIC                          -2526.370
# Sample:                    07-07-2020   HQIC                         -2545.444
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0055      0.188     -0.030      0.976      -0.373       0.362
# ar.L2         -0.0912      0.015     -5.945      0.000      -0.121      -0.061
# ar.L3         -0.0055      0.184     -0.030      0.976      -0.367       0.356
# ma.L1         -0.9934      0.003   -362.617      0.000      -0.999      -0.988
# sigma2         0.0240      0.000    199.830      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       45.84   Jarque-Bera (JB):            838624.30
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.85
# Prob(H) (two-sided):                  0.05   Kurtosis:                        86.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 2)   Log Likelihood                1286.805
# Date:                Sun, 19 Jul 2020   AIC                          -2561.610
# Time:                        23:40:20   BIC                          -2525.821
# Sample:                    07-07-2020   HQIC                         -2548.710
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9694      0.207     -4.683      0.000      -1.375      -0.564
# ar.L2         -0.0960      0.215     -0.447      0.655      -0.517       0.325
# ar.L3         -0.1014      0.015     -6.704      0.000      -0.131      -0.072
# ma.L1         -0.0271      0.030     -0.914      0.361      -0.085       0.031
# ma.L2         -0.9596      0.038    -25.562      0.000      -1.033      -0.886
# sigma2         0.0239      0.000    199.035      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       35.05   Jarque-Bera (JB):            831559.65
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.84
# Prob(H) (two-sided):                  0.04   Kurtosis:                        86.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               pressure   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 3)   Log Likelihood                1285.612
# Date:                Sun, 19 Jul 2020   AIC                          -2557.223
# Time:                        23:40:26   BIC                          -2515.469
# Sample:                    07-07-2020   HQIC                         -2542.173
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8634      0.985     -0.877      0.381      -2.793       1.067
# ar.L2         -0.0225      0.879     -0.026      0.980      -1.744       1.699
# ar.L3         -0.0987      0.027     -3.667      0.000      -0.152      -0.046
# ma.L1         -0.1349      0.966     -0.140      0.889      -2.027       1.758
# ma.L2         -0.9254      0.126     -7.340      0.000      -1.173      -0.678
# ma.L3          0.0693      0.855      0.081      0.935      -1.606       1.745
# sigma2         0.0239      0.000    188.749      0.000       0.024       0.024
# ===================================================================================
# Ljung-Box (Q):                       39.51   Jarque-Bera (JB):            843697.70
# Prob(Q):                              0.49   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             1.86
# Prob(H) (two-sided):                  0.05   Kurtosis:                        86.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print("ARMA(1,1,1):  \t LL = ", results_p_ar_1_i_1_ma_1.llf, "\t AIC = ", results_p_ar_1_i_1_ma_1.aic)
print("ARMA(2,1,1):  \t LL = ", results_p_ar_2_i_1_ma_1.llf, "\t AIC = ", results_p_ar_2_i_1_ma_1.aic)
print("ARMA(3,1,1):  \t LL = ", results_p_ar_3_i_1_ma_1.llf, "\t AIC = ", results_p_ar_3_i_1_ma_1.aic)
print("ARMA(1,2,1):  \t LL = ", results_p_ar_1_i_2_ma_1.llf, "\t AIC = ", results_p_ar_1_i_2_ma_1.aic)
print("ARMA(2,2,1):  \t LL = ", results_p_ar_2_i_2_ma_1.llf, "\t AIC = ", results_p_ar_2_i_2_ma_1.aic)
# Out:
# ARMA(1,1,1):  	 LL =  1276.5930699601174 	 AIC =  -2547.186139920235
# ARMA(2,1,1):  	 LL =  1287.3228103588256 	 AIC =  -2566.645620717651
# ARMA(3,1,1):  	 LL =  1287.3228103588935 	 AIC =  -2564.645620717787
# ARMA(1,2,1):  	 LL =  1271.7320054169618 	 AIC =  -2537.4640108339236
# ARMA(2,2,1):  	 LL =  1283.054442063257 	 AIC =  -2558.108884126514

# %%
df_pred = results_p_ar_2_i_1_ma_1.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.pressure[start_date:end_date].plot(color = "blue")
plt.title("Pressure ARIMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.pressure[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 1.9245671752148046
# MSE 5.109396278246925
