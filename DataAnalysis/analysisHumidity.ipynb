# %% [markdown]
# ## Importing the relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.stats.distributions import chi2 
from math import sqrt
import seaborn as sns
sns.set()
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from influxdb_client import InfluxDBClient

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the Data and Pre-processing

# %%
df = pd.read_csv("dataframe_11g_5m.csv")
df.time = pd.to_datetime(df.time, dayfirst = True)
df.set_index('time',inplace=True)
points_per_day = 288 
n_days = 11
df = df.drop(columns=['pressure', 'temperature', 'people'])
df
# Out:
#                            humidity
# time
# 2020-07-07 13:30:00+00:00     44.45
# 2020-07-07 13:35:00+00:00     44.30
# 2020-07-07 13:40:00+00:00     44.30
# 2020-07-07 13:45:00+00:00     44.05
# 2020-07-07 13:50:00+00:00     44.05
# ...                             ...
# 2020-07-18 13:05:00+00:00     47.35
# 2020-07-18 13:10:00+00:00     47.35
# 2020-07-18 13:15:00+00:00     47.35
# 2020-07-18 13:20:00+00:00     47.35
# 2020-07-18 13:25:00+00:00     47.35
#
# [3168 rows x 1 columns]

# %% [markdown]
# # Fill NaN values

# %%
df['humidity'] = df['humidity'].fillna(method='backfill').fillna(method='ffill')

# %%
points_per_day = int(len(df)/n_days) 
points_per_day
# Out:
# 288

# %%
print(df['humidity'].isnull().sum())
# Out:
# 0

# %% [markdown]
# # Split the dataset

# %%
# divide in train e test
#size = int(len(df)*0.8)
size = len(df)-points_per_day
df_train, df_test = df.iloc[:size], df.iloc[size:]

# %% [markdown]
# # Dickey–Fuller test

# %%
sts.adfuller(df.humidity) # non stazionaria
# Out:
# (-2.508104170625958,
#  0.11351492395948476,
#  18,
#  3149,
#  {'1%': -3.432428322829966,
#   '5%': -2.8624582751958285,
#   '10%': -2.5672588193169945},
#  -734.6126810362912)

# %% [markdown]
# ## The LLR Test

# %%
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.llf
    L2 = mod_2.llf
    LR = (2*(L2-L1))    
    p = chi2.sf(LR, DF).round(3)
    return p

# %% [markdown]
# ## Auto Correlation Function (ACF)

# %%
sgt.plot_acf(df.humidity, zero = False, lags = 1000)
plt.title("ACF 4 humidity", size = 20)
plt.show()

# %% [markdown]
# ## Partial Auto Correlation Function (PACF)

# %%
sgt.plot_pacf(df.humidity, lags = 40, alpha = 0.05, zero = False, method = ('ols'))
plt.title("PACF 4 humidity", size = 20)
plt.show()

# %% [markdown]
# # Humidity

# %%
start_date = df_test.index[0]
end_date = df_test.index[points_per_day-1]

# %% [markdown]
# ## AR

# %%
print("AR(1)")
model_h_ar_1 = SARIMAX(df_train.humidity, order=(1,0,0))
results_h_ar_1 = model_h_ar_1.fit()
print(results_h_ar_1.summary())

print("AR(2)") #PARAMETRI NON SIGNIFICATIVI
model_h_ar_2 = SARIMAX(df_train.humidity, order=(2,0,0))
results_h_ar_2 = model_h_ar_2.fit()
print(results_h_ar_2.summary())

print("AR(3)") #PARAMETRI NON SIGNIFICATIVI
model_h_ar_3 = SARIMAX(df_train.humidity, order=(3,0,0))
results_h_ar_3 = model_h_ar_3.fit()
print(results_h_ar_3.summary())

print("AR(4)") #PARAMETRI NON SIGNIFICATIVI
model_h_ar_4 = ARIMA(df_train.humidity, order=(4,0,0))
results_h_ar_4 = model_h_ar_4.fit()
print(results_h_ar_4.summary())

print("AR(5)") #PARAMETRI NON SIGNIFICATIVI
model_h_ar_5 = ARIMA(df_train.humidity, order=(5,0,0))
results_h_ar_5 = model_h_ar_5.fit()
print(results_h_ar_5.summary())
# Out:
# AR(1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -100.671
# Date:                Sun, 19 Jul 2020   AIC                            205.341
# Time:                        23:19:54   BIC                            217.272
# Sample:                    07-07-2020   HQIC                           209.642
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000    8.5e-05   1.18e+04      0.000       1.000       1.000
# sigma2         0.0626      0.001    118.150      0.000       0.062       0.064
# ===================================================================================
# Ljung-Box (Q):                      937.52   Jarque-Bera (JB):             39962.57
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.97   Skew:                            -1.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -100.671
# Date:                Sun, 19 Jul 2020   AIC                            207.341
# Time:                        23:19:55   BIC                            225.238
# Sample:                    07-07-2020   HQIC                           213.792
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9997      7.108      0.141      0.888     -12.931      14.931
# ar.L2          0.0003      7.108   3.68e-05      1.000     -13.931      13.931
# sigma2         0.0626      0.001    118.090      0.000       0.062       0.064
# ===================================================================================
# Ljung-Box (Q):                      937.52   Jarque-Bera (JB):             39962.66
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.97   Skew:                            -1.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 0, 0)   Log Likelihood                 271.274
# Date:                Sun, 19 Jul 2020   AIC                           -534.547
# Time:                        23:19:57   BIC                           -510.685
# Sample:                    07-07-2020   HQIC                          -525.946
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0023      0.525      1.908      0.056      -0.028       2.032
# ar.L2          0.4775      0.526      0.907      0.364      -0.554       1.509
# ar.L3         -0.4798      0.009    -55.922      0.000      -0.497      -0.463
# sigma2         0.0485      0.000    139.019      0.000       0.048       0.049
# ===================================================================================
# Ljung-Box (Q):                       42.42   Jarque-Bera (JB):             84347.28
# Prob(Q):                              0.37   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -1.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AR(4)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(4, 0)   Log Likelihood                 276.622
# Method:                       css-mle   S.D. of innovations              0.220
# Date:                Sun, 19 Jul 2020   AIC                           -541.244
# Time:                        23:19:57   BIC                           -505.451
# Sample:                    07-07-2020   HQIC                          -528.342
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.8390      2.380     18.844      0.000      40.175      49.503
# ar.L1.humidity     0.9986      0.019     53.640      0.000       0.962       1.035
# ar.L2.humidity     0.4784      0.025     19.312      0.000       0.430       0.527
# ar.L3.humidity    -0.4769      0.025    -19.243      0.000      -0.526      -0.428
# ar.L4.humidity    -0.0016      0.019     -0.088      0.930      -0.038       0.035
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.4486           +0.0000j            1.4486            0.5000
# AR.2            1.0031           +0.0000j            1.0031            0.0000
# AR.3            1.4381           +0.0000j            1.4381            0.0000
# AR.4         -291.5254           +0.0000j          291.5254            0.5000
# -----------------------------------------------------------------------------
# AR(5)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(5, 0)   Log Likelihood                 277.273
# Method:                       css-mle   S.D. of innovations              0.219
# Date:                Sun, 19 Jul 2020   AIC                           -540.546
# Time:                        23:20:00   BIC                           -498.787
# Sample:                    07-07-2020   HQIC                          -525.494
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.8802      2.433     18.443      0.000      40.111      49.650
# ar.L1.humidity     0.9986      0.019     53.659      0.000       0.962       1.035
# ar.L2.humidity     0.4886      0.026     18.565      0.000       0.437       0.540
# ar.L3.humidity    -0.4871      0.026    -18.494      0.000      -0.539      -0.436
# ar.L4.humidity    -0.0229      0.026     -0.869      0.385      -0.074       0.029
# ar.L5.humidity     0.0213      0.019      1.141      0.254      -0.015       0.058
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0029           +0.0000j            1.0029            0.0000
# AR.2           -1.5109           +0.0000j            1.5109            0.5000
# AR.3            1.4982           +0.0000j            1.4982            0.0000
# AR.4           -4.5076           +0.0000j            4.5076            0.5000
# AR.5            4.5924           +0.0000j            4.5924            0.0000
# -----------------------------------------------------------------------------

# %%
print("AR(1):  \t LL = ", results_h_ar_1.llf, "\t AIC = ", results_h_ar_1.aic)
# Out:
# AR(1):  	 LL =  -100.6705441074861 	 AIC =  205.3410882149722

# %%
df_pred = results_h_ar_1.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.humidity[start_date:end_date].plot(color = "blue")
plt.title("Humidity AR: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 2.1921090978884035
# MSE 8.942261932067256

# %% [markdown]
# ## MA

# %%
model_h_ma_1 = SARIMAX(df_train.humidity, order=(0,0,1))
results_h_ma_1 = model_h_ma_1.fit()
print(results_h_ma_1.summary())

model_h_ma_2 = ARIMA(df_train.humidity, order=(0,0,2))
results_h_ma_2 = model_h_ma_2.fit(start_ar_lags=100)
print(results_h_ma_2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(0, 0, 1)   Log Likelihood              -13014.630
# Date:                Sun, 19 Jul 2020   AIC                          26033.260
# Time:                        23:24:22   BIC                          26045.191
# Sample:                    07-07-2020   HQIC                         26037.560
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.9951      0.002    451.204      0.000       0.991       0.999
# sigma2       492.0204     66.854      7.360      0.000     360.989     623.052
# ===================================================================================
# Ljung-Box (Q):                    51585.20   Jarque-Bera (JB):               553.38
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                             0.46
# Prob(H) (two-sided):                  0.06   Kurtosis:                         4.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(0, 2)   Log Likelihood               -5388.333
# Method:                       css-mle   S.D. of innovations              1.570
# Date:                Sun, 19 Jul 2020   AIC                          10784.666
# Time:                        23:24:22   BIC                          10808.529
# Sample:                    07-07-2020   HQIC                         10793.267
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             43.7809      0.102    431.062      0.000      43.582      43.980
# ma.L1.humidity     1.5588      0.008    190.615      0.000       1.543       1.575
# ma.L2.humidity     0.9137      0.007    139.299      0.000       0.901       0.927
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.8530           -0.6057j            1.0462           -0.4017
# MA.2           -0.8530           +0.6057j            1.0462            0.4017
# -----------------------------------------------------------------------------

# %%
print("MA(1):  \t LL = ", results_h_ma_1.llf, "\t AIC = ", results_h_ma_1.aic)
print("MA(2):  \t LL = ", results_h_ma_2.llf, "\t AIC = ", results_h_ma_2.aic)
# Out:
# MA(1):  	 LL =  -13014.62998567981 	 AIC =  26033.25997135962
# MA(2):  	 LL =  -5388.333194435075 	 AIC =  10784.66638887015

# %%
df_pred = results_h_ma_2.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.humidity[start_date:end_date].plot(color = "blue")
plt.title("Humidity MA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 8.356720354249683
# MSE 74.88523226965572

# %% [markdown]
# ## ARMA

# %%
print("\nARMA(1,1)") #NON SIGNIFICATIVO
results_h_ar_1_ma_1 = ARMA(df_train.humidity, order=(1,1)).fit()
print(results_h_ar_1_ma_1.summary())

print("\nARMA(2,1)") 
results_h_ar_2_ma_1 = ARMA(df_train.humidity, order=(2,1)).fit()
print(results_h_ar_2_ma_1.summary())

print("\nARMA(1,2)") #NON SIGNIFICATIVO
results_h_ar_1_ma_2 = ARMA(df_train.humidity, order=(1,2)).fit()
print(results_h_ar_1_ma_2.summary())

print("\nARMA(2,2)") #NON SIGNIFICATIVO
results_h_ar_2_ma_2 = ARMA(df_train.humidity, order=(2,2)).fit()
print(results_h_ar_2_ma_2.summary())

print("\nARMA(3,1)") #NON SIGNIFICATIVO
results_h_ar_3_ma_1 = ARMA(df_train.humidity, order=(3,1)).fit()
print(results_h_ar_3_ma_1.summary())

print("\nARMA(1,3)") #NON SIGNIFICATIVO
results_h_ar_1_ma_3 = ARMA(df_train.humidity, order=(1,3)).fit()
print(results_h_ar_1_ma_3.summary())

print("\nARMA(3,2)") #NON SIGNIFICATIVO
results_h_ar_3_ma_2 = ARMA(df_train.humidity, order=(3,2)).fit()
print(results_h_ar_3_ma_2.summary())

print("\nARMA(2,3)") 
results_h_ar_2_ma_3 = ARMA(df_train.humidity, order=(2,3)).fit()
print(results_h_ar_2_ma_3.summary())

print("\nARMA(3,3)") #NON SIGNIFICATIVO
results_h_ar_3_ma_3 = ARMA(df_train.humidity, order=(3,3)).fit()
print(results_h_ar_3_ma_3.summary())
# Out:
# ARMA(1,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(1, 1)   Log Likelihood                 -97.849
# Method:                       css-mle   S.D. of innovations              0.250
# Date:                Sun, 19 Jul 2020   AIC                            203.698
# Time:                        23:24:59   BIC                            227.560
# Sample:                    07-07-2020   HQIC                           212.299
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             46.1311      3.856     11.964      0.000      38.574      53.688
# ar.L1.humidity     0.9990      0.001   1365.548      0.000       0.998       1.000
# ma.L1.humidity     0.0002      0.013      0.019      0.985      -0.026       0.026
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# MA.1        -4026.4607           +0.0000j         4026.4607            0.5000
# -----------------------------------------------------------------------------
#
# ARMA(2,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(2, 1)   Log Likelihood                  -7.240
# Method:                       css-mle   S.D. of innovations              0.242
# Date:                Sun, 19 Jul 2020   AIC                             24.479
# Time:                        23:25:00   BIC                             54.307
# Sample:                    07-07-2020   HQIC                            35.230
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.5995      2.069     21.554      0.000      40.544      48.655
# ar.L1.humidity     1.8690      0.017    109.376      0.000       1.835       1.902
# ar.L2.humidity    -0.8695      0.017    -50.948      0.000      -0.903      -0.836
# ma.L1.humidity    -0.7444      0.024    -31.447      0.000      -0.791      -0.698
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0041           +0.0000j            1.0041            0.0000
# AR.2            1.1454           +0.0000j            1.1454            0.0000
# MA.1            1.3434           +0.0000j            1.3434            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(1,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(1, 2)   Log Likelihood                 224.991
# Method:                       css-mle   S.D. of innovations              0.224
# Date:                Sun, 19 Jul 2020   AIC                           -439.981
# Time:                        23:25:01   BIC                           -410.153
# Sample:                    07-07-2020   HQIC                          -429.230
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             45.4463      3.125     14.544      0.000      39.322      51.571
# ar.L1.humidity     0.9983      0.001    970.811      0.000       0.996       1.000
# ma.L1.humidity     0.0006      0.018      0.031      0.975      -0.034       0.036
# ma.L2.humidity     0.4339      0.015     29.108      0.000       0.405       0.463
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# MA.1           -0.0006           -1.5182j            1.5182           -0.2501
# MA.2           -0.0006           +1.5182j            1.5182            0.2501
# -----------------------------------------------------------------------------
#
# ARMA(2,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(2, 2)   Log Likelihood                 224.992
# Method:                       css-mle   S.D. of innovations              0.224
# Date:                Sun, 19 Jul 2020   AIC                           -437.985
# Time:                        23:25:02   BIC                           -402.191
# Sample:                    07-07-2020   HQIC                          -425.083
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             45.4431      3.121     14.559      0.000      39.325      51.561
# ar.L1.humidity     1.0022      0.065     15.392      0.000       0.875       1.130
# ar.L2.humidity    -0.0038      0.065     -0.059      0.953      -0.131       0.124
# ma.L1.humidity    -0.0030      0.062     -0.047      0.962      -0.125       0.120
# ma.L2.humidity     0.4339      0.015     29.108      0.000       0.405       0.463
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# AR.2          261.2695           +0.0000j          261.2695            0.0000
# MA.1            0.0034           -1.5182j            1.5182           -0.2496
# MA.2            0.0034           +1.5182j            1.5182            0.2496
# -----------------------------------------------------------------------------
#
# ARMA(3,1)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(3, 1)   Log Likelihood                 276.622
# Method:                       css-mle   S.D. of innovations              0.220
# Date:                Sun, 19 Jul 2020   AIC                           -541.243
# Time:                        23:25:03   BIC                           -505.450
# Sample:                    07-07-2020   HQIC                          -528.342
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.8393      2.380     18.841      0.000      40.175      49.504
# ar.L1.humidity     1.0018      0.033     30.336      0.000       0.937       1.066
# ar.L2.humidity     0.4752      0.037     12.877      0.000       0.403       0.548
# ar.L3.humidity    -0.4786      0.016    -29.254      0.000      -0.511      -0.447
# ma.L1.humidity    -0.0031      0.037     -0.084      0.933      -0.076       0.070
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.4483           +0.0000j            1.4483            0.5000
# AR.2            1.0031           +0.0000j            1.0031            0.0000
# AR.3            1.4383           +0.0000j            1.4383            0.0000
# MA.1          317.5051           +0.0000j          317.5051            0.0000
# -----------------------------------------------------------------------------
#
# ARMA(1,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(1, 3)   Log Likelihood                 224.991
# Method:                       css-mle   S.D. of innovations              0.224
# Date:                Sun, 19 Jul 2020   AIC                           -437.982
# Time:                        23:25:04   BIC                           -402.189
# Sample:                    07-07-2020   HQIC                          -425.081
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             45.4455      3.124     14.549      0.000      39.323      51.568
# ar.L1.humidity     0.9983      0.001    968.998      0.000       0.996       1.000
# ma.L1.humidity     0.0007      0.018      0.037      0.971      -0.035       0.036
# ma.L2.humidity     0.4339      0.015     29.108      0.000       0.405       0.463
# ma.L3.humidity     0.0006      0.017      0.035      0.972      -0.033       0.034
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# MA.1            0.0008           -1.5182j            1.5182           -0.2499
# MA.2            0.0008           +1.5182j            1.5182            0.2499
# MA.3         -738.3662           -0.0000j          738.3662           -0.5000
# -----------------------------------------------------------------------------
#
# ARMA(3,2)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(3, 2)   Log Likelihood                 277.360
# Method:                       css-mle   S.D. of innovations              0.219
# Date:                Sun, 19 Jul 2020   AIC                           -540.720
# Time:                        23:25:05   BIC                           -498.961
# Sample:                    07-07-2020   HQIC                          -525.668
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.8844      2.439     18.406      0.000      40.105      49.664
# ar.L1.humidity     1.0017      0.035     28.841      0.000       0.934       1.070
# ar.L2.humidity     0.4363      0.051      8.613      0.000       0.337       0.536
# ar.L3.humidity    -0.4396      0.037    -11.936      0.000      -0.512      -0.367
# ma.L1.humidity    -0.0031      0.039     -0.079      0.937      -0.079       0.073
# ma.L2.humidity     0.0505      0.042      1.214      0.225      -0.031       0.132
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.5112           +0.0000j            1.5112            0.5000
# AR.2            1.0029           +0.0000j            1.0029            0.0000
# AR.3            1.5008           +0.0000j            1.5008            0.0000
# MA.1            0.0302           -4.4491j            4.4492           -0.2489
# MA.2            0.0302           +4.4491j            4.4492            0.2489
# -----------------------------------------------------------------------------
#
# ARMA(2,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(2, 3)   Log Likelihood                 245.632
# Method:                       css-mle   S.D. of innovations              0.222
# Date:                Sun, 19 Jul 2020   AIC                           -477.264
# Time:                        23:25:07   BIC                           -435.505
# Sample:                    07-07-2020   HQIC                          -462.212
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.5253      1.945     22.892      0.000      40.713      48.337
# ar.L1.humidity     1.9230      0.012    165.402      0.000       1.900       1.946
# ar.L2.humidity    -0.9234      0.012    -79.622      0.000      -0.946      -0.901
# ma.L1.humidity    -0.9184      0.022    -41.837      0.000      -0.961      -0.875
# ma.L2.humidity     0.4426      0.022     20.470      0.000       0.400       0.485
# ma.L3.humidity    -0.3516      0.018    -19.265      0.000      -0.387      -0.316
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0048           +0.0000j            1.0048            0.0000
# AR.2            1.0778           +0.0000j            1.0778            0.0000
# MA.1            1.1457           -0.0000j            1.1457           -0.0000
# MA.2            0.0566           -1.5747j            1.5757           -0.2443
# MA.3            0.0566           +1.5747j            1.5757            0.2443
# -----------------------------------------------------------------------------
#
# ARMA(3,3)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:                     ARMA(3, 3)   Log Likelihood                 277.365
# Method:                       css-mle   S.D. of innovations              0.219
# Date:                Sun, 19 Jul 2020   AIC                           -538.731
# Time:                        23:25:09   BIC                           -491.006
# Sample:                    07-07-2020   HQIC                          -521.529
#                          - 07-17-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             44.8794      2.433     18.448      0.000      40.111      49.647
# ar.L1.humidity     1.0101      0.086     11.747      0.000       0.842       1.179
# ar.L2.humidity     0.4279      0.095      4.526      0.000       0.243       0.613
# ar.L3.humidity    -0.4396      0.037    -11.929      0.000      -0.512      -0.367
# ma.L1.humidity    -0.0116      0.089     -0.130      0.896      -0.186       0.163
# ma.L2.humidity     0.0506      0.042      1.215      0.225      -0.031       0.132
# ma.L3.humidity    -0.0047      0.045     -0.106      0.916      -0.092       0.083
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.5209           +0.0000j            1.5209            0.5000
# AR.2            1.0029           +0.0000j            1.0029            0.0000
# AR.3            1.4914           +0.0000j            1.4914            0.0000
# MA.1           -0.6351           -4.1568j            4.2050           -0.2741
# MA.2           -0.6351           +4.1568j            4.2050            0.2741
# MA.3           11.9875           -0.0000j           11.9875           -0.0000
# -----------------------------------------------------------------------------

# %%
print("ARMA(2,1):  \t LL = ", results_h_ar_2_ma_1.llf, "\t AIC = ", results_h_ar_2_ma_1.aic)
print("ARMA(2,3):  \t LL = ", results_h_ar_2_ma_3.llf, "\t AIC = ", results_h_ar_2_ma_3.aic)
# Out:
# ARMA(2,1):  	 LL =  -7.239607556691226 	 AIC =  24.479215113382452
# ARMA(2,3):  	 LL =  245.6318646548848 	 AIC =  -477.2637293097696

# %%
print("\nARMA(1,1) vs ARMA(2,3) ",LLR_test(results_h_ar_1_ma_1, results_h_ar_2_ma_3, DF=1))
# Out:
# ARMA(1,1) vs ARMA(2,3)  0.0

# %%
df_pred = results_h_ar_2_ma_3.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.humidity[start_date:end_date].plot(color = "blue")
plt.title("Humidity ARMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 2.8371573382266013
# MSE 11.465028171254817

# %% [markdown]
# ## ARIMA

# %%
print("\nARIMA(1,1,1)") #NON SIGNIFICATIVO
results_h_ar_1_i_1_ma_1 = SARIMAX(df_train.humidity, order=(1,1,1)).fit()
print(results_h_ar_1_i_1_ma_1.summary())

print("\nARIMA(2,1,1)")
results_h_ar_2_i_1_ma_1 = SARIMAX(df_train.humidity, order=(2,1,1)).fit()
print(results_h_ar_2_i_1_ma_1.summary())

print("\nARIMA(1,1,2)") #NON SIGNIFICATIVO
results_h_ar_1_i_1_ma_2 = SARIMAX(df_train.humidity, order=(1,1,2)).fit()
print(results_h_ar_1_i_1_ma_2.summary())

print("\nARIMA(1,1,3)") #NON SIGNIFICATIVO
results_h_ar_1_i_1_ma_3 = SARIMAX(df_train.humidity, order=(1,1,3)).fit()
print(results_h_ar_1_i_1_ma_3.summary())

print("\nARIMA(3,1,1)") 
results_h_ar_3_i_1_ma_1 = SARIMAX(df_train.humidity, order=(3,1,1)).fit()
print(results_h_ar_3_i_1_ma_1.summary())

print("\nARIMA(3,1,2)") #NON SIGNIFICATIVO
results_h_ar_3_i_1_ma_2 = SARIMAX(df_train.humidity, order=(3,1,2)).fit()
print(results_h_ar_3_i_1_ma_2.summary())

print("\nARIMA(3,1,3)") 
results_h_ar_3_i_1_ma_3 = SARIMAX(df_train.humidity, order=(3,1,3)).fit()
print(results_h_ar_3_i_1_ma_3.summary())


############################

print("\nARIMA(1,2,1)") 
results_h_ar_1_i_2_ma_1 = SARIMAX(df_train.humidity, order=(1,2,1)).fit()
print(results_h_ar_1_i_2_ma_1.summary())

print("\nARIMA(2,2,1)") 
results_h_ar_2_i_2_ma_1 = SARIMAX(df_train.humidity, order=(2,2,1)).fit()
print(results_h_ar_2_i_2_ma_1.summary())

print("\nARIMA(1,2,2)") 
results_h_ar_1_i_2_ma_2 = SARIMAX(df_train.humidity, order=(1,2,2)).fit()
print(results_h_ar_1_i_2_ma_2.summary())

print("\nARIMA(2,2,2)") #NON SIGNIFICATIVO
results_h_ar_2_i_2_ma_2 = SARIMAX(df_train.humidity, order=(2,2,2)).fit()
print(results_h_ar_2_i_2_ma_2.summary())


print("\nARIMA(1,2,3)") 
results_h_ar_1_i_2_ma_3 = SARIMAX(df_train.humidity, order=(1,2,3)).fit()
print(results_h_ar_1_i_2_ma_3.summary())

print("\nARIMA(3,2,1)") #NON SIGNIFICATIVO
results_h_ar_3_i_2_ma_1 = SARIMAX(df_train.humidity, order=(3,2,1)).fit()
print(results_h_ar_3_i_2_ma_1.summary())

print("\nARIMA(3,2,2)") #NON SIGNIFICATIVO
results_h_ar_3_i_2_ma_2 = SARIMAX(df_train.humidity, order=(3,2,2)).fit()
print(results_h_ar_3_i_2_ma_2.summary())

print("\nARIMA(3,2,3)") #NON SIGNIFICATIVO
results_h_ar_3_i_2_ma_3 = SARIMAX(df_train.humidity, order=(3,2,3)).fit()
print(results_h_ar_3_i_2_ma_3.summary())
# Out:
# ARIMA(1,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                 -95.358
# Date:                Sun, 19 Jul 2020   AIC                            196.717
# Time:                        23:27:00   BIC                            214.612
# Sample:                    07-07-2020   HQIC                           203.167
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1        1.54e-07   6819.709   2.26e-11      1.000   -1.34e+04    1.34e+04
# ma.L1      -3.013e-07   8823.975  -3.41e-11      1.000   -1.73e+04    1.73e+04
# sigma2         0.0626      0.001    117.458      0.000       0.062       0.064
# ===================================================================================
# Ljung-Box (Q):                      937.66   Jarque-Bera (JB):             39957.84
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.97   Skew:                            -1.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.82e+15. Standard errors may be unstable.
#
# ARIMA(2,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                 277.697
# Date:                Sun, 19 Jul 2020   AIC                           -547.393
# Time:                        23:27:00   BIC                           -523.533
# Sample:                    07-07-2020   HQIC                          -538.793
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       2.665e-08   1.23e-09     21.607      0.000    2.42e-08    2.91e-08
# ar.L2          0.4778      0.008     56.358      0.000       0.461       0.494
# ma.L1      -1.464e-07   1.53e-09    -95.441      0.000   -1.49e-07   -1.43e-07
# sigma2         0.0483      0.000    142.185      0.000       0.048       0.049
# ===================================================================================
# Ljung-Box (Q):                       42.44   Jarque-Bera (JB):             84546.83
# Prob(Q):                              0.37   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.64e+30. Standard errors may be unstable.
#
# ARIMA(1,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 2)   Log Likelihood                 227.013
# Date:                Sun, 19 Jul 2020   AIC                           -446.027
# Time:                        23:27:01   BIC                           -422.166
# Sample:                    07-07-2020   HQIC                          -437.426
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1        1.99e-05    730.184   2.73e-08      1.000   -1431.134    1431.134
# ma.L1      -1.201e-05    641.249  -1.87e-08      1.000   -1256.826    1256.826
# ma.L2          0.4335      0.011     39.246      0.000       0.412       0.455
# sigma2         0.0500      0.000    135.714      0.000       0.049       0.051
# ===================================================================================
# Ljung-Box (Q):                      168.56   Jarque-Bera (JB):             68212.11
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.88   Skew:                            -1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 1, 3)   Log Likelihood                 227.013
# Date:                Sun, 19 Jul 2020   AIC                           -444.027
# Time:                        23:27:01   BIC                           -414.201
# Sample:                    07-07-2020   HQIC                          -433.276
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       2.298e-05    527.348   4.36e-08      1.000   -1033.582    1033.582
# ma.L1      -2.611e-05    525.799  -4.97e-08      1.000   -1030.547    1030.547
# ma.L2          0.4335      0.030     14.234      0.000       0.374       0.493
# ma.L3      -8.856e-06    283.030  -3.13e-08      1.000    -554.728     554.728
# sigma2         0.0500      0.000    135.698      0.000       0.049       0.051
# ===================================================================================
# Ljung-Box (Q):                      168.56   Jarque-Bera (JB):             68212.09
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.88   Skew:                            -1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.17e+17. Standard errors may be unstable.
#
# ARIMA(3,1,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 1)   Log Likelihood                 277.697
# Date:                Sun, 19 Jul 2020   AIC                           -545.393
# Time:                        23:27:02   BIC                           -515.567
# Sample:                    07-07-2020   HQIC                          -534.643
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1      -4.155e-08   1.23e-09    -33.752      0.000    -4.4e-08   -3.91e-08
# ar.L2          0.4778      0.008     56.358      0.000       0.461       0.494
# ar.L3       1.427e-07   7.58e-10    188.378      0.000    1.41e-07    1.44e-07
# ma.L1      -1.461e-07   1.37e-09   -106.356      0.000   -1.49e-07   -1.43e-07
# sigma2         0.0483      0.000    142.185      0.000       0.048       0.049
# ===================================================================================
# Ljung-Box (Q):                       42.44   Jarque-Bera (JB):             84546.83
# Prob(Q):                              0.37   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.13e+29. Standard errors may be unstable.
#
# ARIMA(3,1,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 2)   Log Likelihood                 278.545
# Date:                Sun, 19 Jul 2020   AIC                           -545.090
# Time:                        23:27:03   BIC                           -509.299
# Sample:                    07-07-2020   HQIC                          -532.189
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1       2.236e-05    279.290   8.01e-08      1.000    -547.398     547.398
# ar.L2          0.4360      0.032     13.438      0.000       0.372       0.500
# ar.L3       -4.31e-06    402.482  -1.07e-08      1.000    -788.850     788.850
# ma.L1      -2.857e-05    273.031  -1.05e-07      1.000    -535.132     535.132
# ma.L2          0.0540      0.037      1.470      0.142      -0.018       0.126
# sigma2         0.0482      0.000    139.860      0.000       0.048       0.049
# ===================================================================================
# Ljung-Box (Q):                       41.39   Jarque-Bera (JB):             83425.87
# Prob(Q):                              0.41   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.44e+16. Standard errors may be unstable.
#
# ARIMA(3,1,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 1, 3)   Log Likelihood                 278.545
# Date:                Sun, 19 Jul 2020   AIC                           -543.090
# Time:                        23:27:06   BIC                           -501.334
# Sample:                    07-07-2020   HQIC                          -528.039
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1      -2.533e-08   1.06e-08     -2.382      0.017   -4.62e-08   -4.48e-09
# ar.L2          0.4357      0.017     26.112      0.000       0.403       0.468
# ar.L3       1.185e-07   1.29e-08      9.166      0.000    9.31e-08    1.44e-07
# ma.L1      -1.465e-07   1.85e-09    -79.187      0.000    -1.5e-07   -1.43e-07
# ma.L2          0.0543      0.019      2.794      0.005       0.016       0.092
# ma.L3      -1.274e-07   2.16e-08     -5.902      0.000    -1.7e-07   -8.51e-08
# sigma2         0.0482      0.000    140.021      0.000       0.048       0.049
# ===================================================================================
# Ljung-Box (Q):                       41.39   Jarque-Bera (JB):             83419.74
# Prob(Q):                              0.41   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.52e+29. Standard errors may be unstable.
#
# ARIMA(1,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 1)   Log Likelihood                  93.513
# Date:                Sun, 19 Jul 2020   AIC                           -181.026
# Time:                        23:27:07   BIC                           -163.131
# Sample:                    07-07-2020   HQIC                          -174.575
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5877      0.012    -50.638      0.000      -0.610      -0.565
# ma.L1         -0.3280      0.020    -16.714      0.000      -0.366      -0.289
# sigma2         0.0548      0.000    124.949      0.000       0.054       0.056
# ===================================================================================
# Ljung-Box (Q):                      182.65   Jarque-Bera (JB):             58342.62
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.95   Skew:                            -0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                        25.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 1)   Log Likelihood                 273.861
# Date:                Sun, 19 Jul 2020   AIC                           -539.723
# Time:                        23:27:08   BIC                           -515.863
# Sample:                    07-07-2020   HQIC                          -531.122
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0004      0.140      0.003      0.998      -0.273       0.274
# ar.L2          0.4782      0.009     55.351      0.000       0.461       0.495
# ma.L1         -1.0000      0.051    -19.679      0.000      -1.100      -0.900
# sigma2         0.0483      0.002     19.944      0.000       0.044       0.053
# ===================================================================================
# Ljung-Box (Q):                       42.65   Jarque-Bera (JB):             84768.23
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 2)   Log Likelihood                 131.569
# Date:                Sun, 19 Jul 2020   AIC                           -255.138
# Time:                        23:27:08   BIC                           -231.279
# Sample:                    07-07-2020   HQIC                          -246.538
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7710      0.025    -30.589      0.000      -0.820      -0.722
# ma.L1         -0.1814      0.057     -3.166      0.002      -0.294      -0.069
# ma.L2         -0.3006      0.031     -9.640      0.000      -0.362      -0.239
# sigma2         0.0534      0.000    122.085      0.000       0.053       0.054
# ===================================================================================
# Ljung-Box (Q):                      195.86   Jarque-Bera (JB):             73284.23
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.02   Skew:                            -0.86
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(2,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(2, 2, 2)   Log Likelihood                 273.861
# Date:                Sun, 19 Jul 2020   AIC                           -537.722
# Time:                        23:27:11   BIC                           -507.898
# Sample:                    07-07-2020   HQIC                          -526.972
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0005      0.374      0.001      0.999      -0.733       0.734
# ar.L2          0.4779      0.009     55.188      0.000       0.461       0.495
# ma.L1         -1.0000      0.591     -1.691      0.091      -2.159       0.159
# ma.L2       4.355e-05      0.591   7.36e-05      1.000      -1.159       1.159
# sigma2         0.0483      0.001     34.040      0.000       0.046       0.051
# ===================================================================================
# Ljung-Box (Q):                       42.66   Jarque-Bera (JB):             84760.79
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(1,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(1, 2, 3)   Log Likelihood                 229.341
# Date:                Sun, 19 Jul 2020   AIC                           -448.682
# Time:                        23:27:13   BIC                           -418.858
# Sample:                    07-07-2020   HQIC                          -437.932
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1413      0.097     -1.453      0.146      -0.332       0.049
# ma.L1         -0.8597      0.082    -10.546      0.000      -1.019      -0.700
# ma.L2          0.3097      0.078      3.956      0.000       0.156       0.463
# ma.L3         -0.3989      0.012    -31.976      0.000      -0.423      -0.374
# sigma2         0.0499      0.000    127.639      0.000       0.049       0.051
# ===================================================================================
# Ljung-Box (Q):                      120.95   Jarque-Bera (JB):             75020.45
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 1)   Log Likelihood                 273.860
# Date:                Sun, 19 Jul 2020   AIC                           -537.719
# Time:                        23:27:16   BIC                           -507.895
# Sample:                    07-07-2020   HQIC                          -526.969
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0003      0.281      0.001      0.999      -0.551       0.551
# ar.L2          0.4781      0.009     55.312      0.000       0.461       0.495
# ar.L3          0.0003      0.283      0.001      0.999      -0.554       0.554
# ma.L1         -0.9999      0.011    -93.518      0.000      -1.021      -0.979
# sigma2         0.0483      0.001     84.456      0.000       0.047       0.049
# ===================================================================================
# Ljung-Box (Q):                       42.65   Jarque-Bera (JB):             84763.56
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.93   Skew:                            -1.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 2)   Log Likelihood                 274.924
# Date:                Sun, 19 Jul 2020   AIC                           -537.848
# Time:                        23:27:18   BIC                           -502.059
# Sample:                    07-07-2020   HQIC                          -524.948
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9560      0.142     -6.727      0.000      -1.235      -0.677
# ar.L2          0.4785      0.137      3.499      0.000       0.210       0.746
# ar.L3          0.4513      0.033     13.491      0.000       0.386       0.517
# ma.L1         -0.0391      0.054     -0.731      0.465      -0.144       0.066
# ma.L2         -0.9606      0.067    -14.395      0.000      -1.091      -0.830
# sigma2         0.0482      0.001     75.752      0.000       0.047       0.049
# ===================================================================================
# Ljung-Box (Q):                       40.97   Jarque-Bera (JB):             86362.33
# Prob(Q):                              0.43   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.94   Skew:                            -1.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# ARIMA(3,2,3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               humidity   No. Observations:                 2880
# Model:               SARIMAX(3, 2, 3)   Log Likelihood                 275.012
# Date:                Sun, 19 Jul 2020   AIC                           -536.024
# Time:                        23:27:25   BIC                           -494.270
# Sample:                    07-07-2020   HQIC                          -520.974
#                          - 07-17-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9416      0.295     -3.195      0.001      -1.519      -0.364
# ar.L2          0.4902      0.296      1.656      0.098      -0.090       1.070
# ar.L3          0.4495      0.033     13.665      0.000       0.385       0.514
# ma.L1         -0.0568      0.444     -0.128      0.898      -0.927       0.813
# ma.L2         -0.9584      0.066    -14.444      0.000      -1.088      -0.828
# ma.L3          0.0154      0.438      0.035      0.972      -0.843       0.874
# sigma2         0.0482      0.001     68.707      0.000       0.047       0.050
# ===================================================================================
# Ljung-Box (Q):                       40.79   Jarque-Bera (JB):             86514.81
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.94   Skew:                            -1.12
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print("ARMA(2,1,1):  \t LL = ", results_h_ar_2_i_1_ma_1.llf, "\t AIC = ", results_h_ar_2_i_1_ma_1.aic)
print("ARMA(3,1,1):  \t LL = ", results_h_ar_3_i_1_ma_1.llf, "\t AIC = ", results_h_ar_3_i_1_ma_1.aic)
print("ARMA(3,1,3):  \t LL = ", results_h_ar_3_i_1_ma_3.llf, "\t AIC = ", results_h_ar_3_i_1_ma_3.aic)
print("ARMA(1,2,1):  \t LL = ", results_h_ar_1_i_2_ma_1.llf, "\t AIC = ", results_h_ar_1_i_2_ma_1.aic)
print("ARMA(2,2,1):  \t LL = ", results_h_ar_2_i_2_ma_1.llf, "\t AIC = ", results_h_ar_2_i_2_ma_1.aic)
print("ARMA(1,2,2):  \t LL = ", results_h_ar_1_i_2_ma_2.llf, "\t AIC = ", results_h_ar_1_i_2_ma_2.aic)
print("ARMA(1,2,3):  \t LL = ", results_h_ar_1_i_2_ma_3.llf, "\t AIC = ", results_h_ar_1_i_2_ma_3.aic)
# Out:
# ARMA(2,1,1):  	 LL =  277.696723905932 	 AIC =  -547.393447811864
# ARMA(3,1,1):  	 LL =  277.6967239044957 	 AIC =  -545.3934478089914
# ARMA(3,1,3):  	 LL =  278.54495784316333 	 AIC =  -543.0899156863267
# ARMA(1,2,1):  	 LL =  93.5128442253741 	 AIC =  -181.0256884507482
# ARMA(2,2,1):  	 LL =  273.86125585274976 	 AIC =  -539.7225117054995
# ARMA(1,2,2):  	 LL =  131.56912102495406 	 AIC =  -255.13824204990811
# ARMA(1,2,3):  	 LL =  229.34118353025602 	 AIC =  -448.68236706051204

# %%
df_pred = results_h_ar_2_i_1_ma_1.predict(start = start_date, end = end_date)

df_pred[start_date:end_date].plot(figsize = (20,5), color = "red")
df_test.humidity[start_date:end_date].plot(color = "blue")
plt.title("Humidity ARIMA: Predictions vs Actual", size = 24)
plt.show()                          

print("MAE "+str(mean_absolute_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
print("MSE "+str(mean_squared_error(df_test.humidity[start_date:end_date], df_pred[start_date:end_date])))
# Out:
# MAE 2.3298202921328515
# MSE 9.882680255372454
